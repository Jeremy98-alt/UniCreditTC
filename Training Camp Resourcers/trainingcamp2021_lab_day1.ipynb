# %% [markdown]
# # Day1 - Traditional ML methods for KG completion
#
# In this lab you will learn:
# - how to read a Knowledge Graph using NetworkX
# - how to build a simple threshold model based on graph topological features
# - how to train a classifier using the topological features of the graph

# %%
import pandas as pd
import networkx as nx
from collections import defaultdict
import random
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
import numpy as np
from tqdm import tqdm

# %%
#Given a dataframe, generate a list with all the triples and another list with the "negative" relations
def generate_pos_neg_relations(df, number_neg_rel_triple=1):
    pairs=defaultdict(list)
    relations=defaultdict(list)
    for i in df.iterrows():
        s = i[1]['source']
        t = i[1]['tail']
        r = i[1][1]
      #  print(s,t,r)
        pairs[(s,t)].append(r)
        relations[r].append((s,t))
    
    sourceList=set()
    targetList=set()
    for i in list(pairs.keys()):
        if type(i)==int:
            break
        sourceList.add(i[0])
        targetList.add(i[1])
    
    negative_relations = defaultdict(list)
    for rel, p in relations.items():
        rel_targets = set()
        for i in p:
            rel_targets.add(i[1])
        candidate_targets = targetList.difference(rel_targets)
        
        for i,j in p:
            negative_targets = random.choices(list(candidate_targets),
                                          k=(min(len(candidate_targets),number_neg_rel_triple)))
            for t in negative_targets:
                negative_relations[rel].append((i,t))
    return relations,negative_relations

# %%
# Given a graph, the corresponding undirected graph and the corresponding undirected and 
# unweighted graph, it computes some topological node features
def reachable_from_rel(s,r):
    reachable=set()
    if s in Gtrain:
        for n,i in Gtrain[s].items():
            if r==i[0][1]:
                reachable.add(n)
    return reachable



def compute_features(G,GUnd,GUndSimple,i,j,rel=None):
    cn=aa=jc=ind_i = outd_i = ind_j = outd_j =0
    
    if ((i in GUnd) and (j in GUnd)):
        cn = len(list(nx.common_neighbors(GUnd, i,j)))
   # if ((i in GUndSimple) and (j in GUndSimple)):
   #     aa =[aa for u,v,aa in nx.adamic_adar_index(GUndSimple, [(i,j)])][0]
    if ((i in GUndSimple) and (j in GUndSimple)):
        jc = [jc for u,v,jc in nx.jaccard_coefficient(GUndSimple, [(i,j)])][0]
    if (i in G):
        ind_i = G.in_degree(i)
        outd_i = G.out_degree(i)
    if (j in G):
        ind_j = G.in_degree(j)
        outd_j = G.out_degree(j)
    '''
    if rel:
        rel_s=len(reachable_from_rel(i,rel))
        rel_t=len(reachable_from_rel(j,rel))
        common_rel_s_t=len(reachable_from_rel(i,rel).intersection(reachable_from_rel(j,rel)))
        union_rel_s_t=len(reachable_from_rel(i,rel).union(reachable_from_rel(j,rel)))
        jaccard_rel_s_t=0
        if union_rel_s_t>0:
            jaccard_rel_s_t=(union_rel_s_t-common_rel_s_t)/union_rel_s_t
    '''   
    #print(i,j,cn,aa,jc,ind_i,ind_j,outd_i,outd_j)
    return cn,jc,ind_i,ind_j,outd_i,outd_j

# %%
def computeF1(df_res):
    tn = df_res['tn'].sum()
    tp = df_res['tp'].sum()
    fn = df_res['fn'].sum()
    fp = df_res['fp'].sum() 
    precision = tp/(tp+fp)
    recall = tp / (tp+fn)
    F1 = 2 * (precision * recall) / (precision + recall)
    return F1

# %%
#Given a triple, compute some node features
def compute_triples_features(G,GUnd,GUndSimple,rel,triple,label):
    curr_triples_feature={}
    curr_triples_feature['relation'] = rel
    curr_triples_feature['label'] = label
    curr_triples_feature['source'] = triple[0]
    curr_triples_feature['target'] = triple[1]
    for ix,feature in enumerate(compute_features(G,GUnd,GUndSimple,triple[0],triple[1],rel)):
        curr_triples_feature['f'+str(ix)] = feature
    return curr_triples_feature

# %%
#Compute featurees for each positive and negative relation
def generate_df_features(G,relations,negative_relations=None):
    triples=[]
    GUnd = G.to_undirected()
    GUndSimple = nx.Graph(GUnd)
    for rel in relations.keys():
        for posTriple in relations[rel]:
            triples.append(compute_triples_features(G,GUnd,GUndSimple,rel,posTriple,1))
        if negative_relations:
            for negTriple in negative_relations[rel]:
                triples.append(compute_triples_features(G,GUnd,GUndSimple,rel,negTriple,0))
    df_rel = pd.DataFrame(triples)
    return df_rel

# %% [markdown]
# # Read dataset
#
# We use the Kinship KG, you can download it at https://github.com/ZhenfengLei/KGDatasets/tree/master/Kinship

# %%
#train = pd.read_csv('KGDatasets/FB15k-237/train.txt',sep='\t',header=None)
#validation =  pd.read_csv('KGDatasets/FB15k-237/valid.txt',sep='\t',header=None)
#test =  pd.read_csv('KGDatasets/FB15k-237/test.txt',sep='\t',header=None)
#entity2id_df =  pd.read_csv('KGDatasets/FB15k-237/entity2id.txt',sep='\t',header=None)
#entity2id =  dict(zip(entity2id_df[0], entity2id_df[1]))

# %%
train = pd.read_csv('KGDatasets/Kinship/train.txt',sep='\t',header=None)
validation =  pd.read_csv('KGDatasets/Kinship/valid.txt',sep='\t',header=None)
test =  pd.read_csv('KGDatasets/Kinship/test.txt',sep='\t',header=None)
entity2id_df =  pd.read_csv('KGDatasets/Kinship/entity2id.txt',sep='\t',header=None)
entity2id =  dict(zip(entity2id_df[0], entity2id_df[1]))

# %%
train.sample(5)
# Out:
#              0       1         2
# 7168  person88   term8  person21
# 822   person94  term22  person71
# 7736  person50   term5  person14
# 7372  person20   term0  person39
# 3282   person5  term15  person94

# %%
test.sample(5)
# Out:
#              0       1         2
# 666   person33  term12  person35
# 530   person33   term8  person16
# 799   person75   term9  person25
# 1006  person78  term22  person70
# 657   person50   term8  person41

# %%
validation.sample(5)
# Out:
#              0       1         2
# 1065  person57  term15  person68
# 857   person24   term9  person32
# 173   person47  term18  person58
# 339   person82  term16  person40
# 914   person47  term13  person93

# %%
train['source'] = train[0].apply(lambda x: entity2id[x])
train['tail'] = train[2].apply(lambda x: entity2id[x])
test['source'] = test[0].apply(lambda x: entity2id[x])
test['tail'] = test[2].apply(lambda x: entity2id[x])
validation['source'] = validation[0].apply(lambda x: entity2id[x])
validation['tail'] = validation[2].apply(lambda x: entity2id[x])

# %% [markdown]
# # Create the train MultiDigraph

# %% [markdown]
# We represent the KG as a Multi-Directed graph. We use NetworkX (full documentation at https://networkx.org/documentation/stable/ ) to convert the Pandas DataFrame in a graph.

# %%
Gtrain=nx.from_pandas_edgelist(train, source='source', target='tail', edge_attr=1, create_using=nx.MultiDiGraph)

# %%
print('Train-> Nodes:{} Edges:{}'.format(Gtrain.number_of_nodes(),Gtrain.number_of_edges()))
# Out:
# Train-> Nodes:104 Edges:8544

# %% [markdown]
# In NetworkX, some functions (e.g. Common Neighbors) are only defined on simple and undirected graphs.
# For this reason, we transform the train MultiDigraph in a (simple) undirected graph

# %%
GtrainUnd = Gtrain.to_undirected()
GtrainSimple = nx.DiGraph(Gtrain)
GtrainUndSimple = nx.Graph(GtrainUnd)

# %% [markdown]
# ## Add negative relations to train, test and validation set

# %% [markdown]
# In order to properly train and thest our models, out training, validation and test set should include negative examples i.e. triples not in the graph. In the following, ee generate such triples.
#
# Notice that in the dataset Kaggle competition both training and test set have already some negative examples (however, you might want to increase the negative riples in the training set)

# %%
number_neg_rel_triple = 1
print("Generate list of positive and negative relations in the training set..")
rel_train,negrel_train = generate_pos_neg_relations(train,number_neg_rel_triple)
print("Generate list of positive and negative relations in the validation set..")
rel_validation,negrel_validation = generate_pos_neg_relations(validation,number_neg_rel_triple)
print("Generate list of positive and negative relations in the test set..")
rel_test,negrel_test = generate_pos_neg_relations(test,number_neg_rel_triple)
# Out:
# Generate list of positive and negative relations in the training set..
# Generate list of positive and negative relations in the validation set..
# Generate list of positive and negative relations in the test set..

# %% [markdown]
# ## Generate node features for the training set
# In the following, we generate some topological features for training, validation and test sets.

# %% [markdown]
# ### Training set

# %%
print("Generate edge fetures..")
df_train = generate_df_features(Gtrain,rel_train,negrel_train).sample(frac=1)
df_train.sample(5)
# Out:
# Generate edge fetures..
#       relation  label  source  target  f0        f1  f2  f3  f4  f5
# 9537     term1      1      43      92  98  0.942308  85  87  81  84
# 11746   term13      0      64      18  98  0.942308  78  83  89  83
# 15066    term3      1      38      17  97  0.932692  84  72  88  83
# 6589    term17      1      58     101  92  0.884615  84  81  80  83
# 5174     term8      0     101      68  92  0.884615  81  82  83  76

# %% [markdown]
# ### Validation set

# %%
print("Generate edge fetures..")
df_validation = generate_df_features(Gtrain,rel_validation,negrel_validation).sample(frac=1)
df_validation.sample(5)
# Out:
# Generate edge fetures..
#      relation  label  source  target  f0        f1  f2  f3  f4  f5
# 1214    term3      1      84      47  94  0.921569  81  70  85  82
# 761    term11      1      75      58  92  0.884615  80  84  81  80
# 2014   term22      1      59      63  93  0.894231  77  91  78  79
# 1001    term8      0      63      40  98  0.942308  91  85  79  89
# 840    term11      0      84     103  95  0.931373  81  80  85  76

# %% [markdown]
# ### Test set

# %%
print("Generate edge fetures..")
df_test = generate_df_features(Gtrain,rel_test,negrel_test).sample(frac=1) #shuffle
df_test.sample(5)
# Out:
# Generate edge fetures..
#      relation  label  source  target  f0        f1  f2  f3  f4  f5
# 1467   term17      1      37       6  97  0.932692  87  79  80  82
# 383    term10      1      90      13  96  0.923077  87  78  87  86
# 509    term18      1      77      72  95  0.931373  83  85  84  85
# 1041   term15      0       8      59  90  0.865385  77  77  83  78
# 85     term11      1      10      15  91  0.900990  85  80  75  80

# %% [markdown]
# ## 1) Combine node features for each relation

# %%
def get_threshold_score(r,df_train,df_validation,feature_name): 
    df_train_rel = df_train[(df_train.relation==r) & (df_train.label==1)]
    #
    df_train_rel['score']=df_train_rel['label']*df_train_rel[feature_name]
    train_score = df_train_rel['score'].mean(axis=0)
    
    
    y_validation = df_validation[df_validation.relation==r]['label']
    X_validation = df_validation[df_validation.relation==r][feature_name]
    #print(df_validation[df_validation.relation==r].apply(lambda x: 1 if (x['f0']>train_score) else 0))
    pred_class_validation = X_validation>train_score
   # print(pred_class_validation)
   # print(y_validation,pred_class_validation)
    tn, fp, fn, tp = metrics.confusion_matrix(y_validation,pred_class_validation).ravel()
    return {'train':df_train_rel.shape[0],'test':y_validation.shape[0],
            'tn':tn,'fp':fp,'fn':fn,'tp':tp,
            'precision':metrics.precision_score(y_validation,pred_class_validation),
            'recall':metrics.recall_score(y_validation,pred_class_validation),
            'accuracy':metrics.accuracy_score(y_validation,pred_class_validation),
            'F1':metrics.f1_score(y_validation,pred_class_validation)}

# %%
features = ['f0','f1','f2','f3','f4','f5']
threshold_score =[]
for feat in features:
    baseline_validation = []
    for r in rel_validation.keys():
        res = get_threshold_score(r,df_train,df_validation,feat)
        print("{}: train {}, test {}, tn {},fp {},fn {},tp {},precision {}, recall {},accuracy {}, f1-score {}"
              .format(r,res['train'],res['test'],res['tn'],res['fp'],res['fn'],res['tp']
                      ,res['precision'],res['recall'],res['accuracy'],res['F1']))
        baseline_validation.append(res)
    f1 = computeF1(pd.DataFrame(baseline_validation))
    threshold_score.append((feat,f1))
threshold_score
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# term12: train 236, test 66, tn 22,fp 11,fn 17,tp 16,precision 0.5925925925925926, recall 0.48484848484848486,accuracy 0.5757575757575758, f1-score 0.5333333333333333
# term5: train 404, test 124, tn 34,fp 28,fn 35,tp 27,precision 0.4909090909090909, recall 0.43548387096774194,accuracy 0.49193548387096775, f1-score 0.4615384615384615
# term15: train 757, test 190, tn 44,fp 51,fn 40,tp 55,precision 0.5188679245283019, recall 0.5789473684210527,accuracy 0.5210526315789473, f1-score 0.5472636815920399
# term16: train 1004, test 242, tn 52,fp 69,fn 52,tp 69,precision 0.5, recall 0.5702479338842975,accuracy 0.5, f1-score 0.5328185328185328
# term1: train 384, test 92, tn 19,fp 27,fn 19,tp 27,precision 0.5, recall 0.5869565217391305,accuracy 0.5, f1-score 0.54
# term11: train 600, test 134, tn 34,fp 33,fn 32,tp 35,precision 0.5147058823529411, recall 0.5223880597014925,accuracy 0.5149253731343284, f1-score 0.5185185185185184
# term8: train 637, test 156, tn 41,fp 37,fn 43,tp 35,precision 0.4861111111111111, recall 0.44871794871794873,accuracy 0.48717948717948717, f1-score 0.4666666666666667
# term0: train 185, test 52, tn 14,fp 12,fn 13,tp 13,precision 0.52, recall 0.5,accuracy 0.5192307692307693, f1-score 0.5098039215686274
# term13: train 367, test 64, tn 19,fp 13,fn 17,tp 15,precision 0.5357142857142857, recall 0.46875,accuracy 0.53125, f1-score 0.5
# term17: train 320, test 70, tn 11,fp 24,fn 17,tp 18,precision 0.42857142857142855, recall 0.5142857142857142,accuracy 0.4142857142857143, f1-score 0.4675324675324675
# term3: train 299, test 90, tn 28,fp 17,fn 18,tp 27,precision 0.6136363636363636, recall 0.6,accuracy 0.6111111111111112, f1-score 0.6067415730337078
# term7: train 663, test 142, tn 35,fp 36,fn 30,tp 41,precision 0.5324675324675324, recall 0.5774647887323944,accuracy 0.5352112676056338, f1-score 0.5540540540540541
# term9: train 370, test 106, tn 26,fp 27,fn 25,tp 28,precision 0.509090909090909, recall 0.5283018867924528,accuracy 0.5094339622641509, f1-score 0.5185185185185185
# term2: train 183, test 54, tn 13,fp 14,fn 11,tp 16,precision 0.5333333333333333, recall 0.5925925925925926,accuracy 0.5370370370370371, f1-score 0.5614035087719299
# term10: train 392, test 98, tn 33,fp 16,fn 20,tp 29,precision 0.6444444444444445, recall 0.5918367346938775,accuracy 0.6326530612244898, f1-score 0.6170212765957447
# term14: train 34, test 14, tn 1,fp 6,fn 3,tp 4,precision 0.4, recall 0.5714285714285714,accuracy 0.35714285714285715, f1-score 0.47058823529411764
# term4: train 393, test 110, tn 32,fp 23,fn 30,tp 25,precision 0.5208333333333334, recall 0.45454545454545453,accuracy 0.5181818181818182, f1-score 0.48543689320388356
# term18: train 460, test 108, tn 30,fp 24,fn 29,tp 25,precision 0.5102040816326531, recall 0.46296296296296297,accuracy 0.5092592592592593, f1-score 0.48543689320388356
# term6: train 370, test 82, tn 16,fp 25,fn 21,tp 20,precision 0.4444444444444444, recall 0.4878048780487805,accuracy 0.43902439024390244, f1-score 0.46511627906976744
# term22: train 153, test 46, tn 15,fp 8,fn 9,tp 14,precision 0.6363636363636364, recall 0.6086956521739131,accuracy 0.6304347826086957, f1-score 0.6222222222222223
# term21: train 106, test 40, tn 9,fp 11,fn 6,tp 14,precision 0.56, recall 0.7,accuracy 0.575, f1-score 0.6222222222222222
# term20: train 209, test 56, tn 18,fp 10,fn 15,tp 13,precision 0.5652173913043478, recall 0.4642857142857143,accuracy 0.5535714285714286, f1-score 0.5098039215686274
# term12: train 236, test 66, tn 19,fp 14,fn 14,tp 19,precision 0.5757575757575758, recall 0.5757575757575758,accuracy 0.5757575757575758, f1-score 0.5757575757575758
# term5: train 404, test 124, tn 33,fp 29,fn 29,tp 33,precision 0.532258064516129, recall 0.532258064516129,accuracy 0.532258064516129, f1-score 0.532258064516129
# term15: train 757, test 190, tn 42,fp 53,fn 36,tp 59,precision 0.5267857142857143, recall 0.6210526315789474,accuracy 0.531578947368421, f1-score 0.5700483091787439
# term16: train 1004, test 242, tn 49,fp 72,fn 44,tp 77,precision 0.5167785234899329, recall 0.6363636363636364,accuracy 0.5206611570247934, f1-score 0.5703703703703703
# term1: train 384, test 92, tn 18,fp 28,fn 13,tp 33,precision 0.5409836065573771, recall 0.717391304347826,accuracy 0.5543478260869565, f1-score 0.6168224299065421
# term11: train 600, test 134, tn 32,fp 35,fn 29,tp 38,precision 0.5205479452054794, recall 0.5671641791044776,accuracy 0.5223880597014925, f1-score 0.5428571428571428
# term8: train 637, test 156, tn 36,fp 42,fn 41,tp 37,precision 0.46835443037974683, recall 0.47435897435897434,accuracy 0.46794871794871795, f1-score 0.4713375796178344
# term0: train 185, test 52, tn 13,fp 13,fn 11,tp 15,precision 0.5357142857142857, recall 0.5769230769230769,accuracy 0.5384615384615384, f1-score 0.5555555555555555
# term13: train 367, test 64, tn 19,fp 13,fn 15,tp 17,precision 0.5666666666666667, recall 0.53125,accuracy 0.5625, f1-score 0.5483870967741935
# term17: train 320, test 70, tn 11,fp 24,fn 15,tp 20,precision 0.45454545454545453, recall 0.5714285714285714,accuracy 0.44285714285714284, f1-score 0.5063291139240506
# term3: train 299, test 90, tn 28,fp 17,fn 13,tp 32,precision 0.6530612244897959, recall 0.7111111111111111,accuracy 0.6666666666666666, f1-score 0.6808510638297872
# term7: train 663, test 142, tn 35,fp 36,fn 27,tp 44,precision 0.55, recall 0.6197183098591549,accuracy 0.5563380281690141, f1-score 0.5827814569536425
# term9: train 370, test 106, tn 23,fp 30,fn 20,tp 33,precision 0.5238095238095238, recall 0.6226415094339622,accuracy 0.5283018867924528, f1-score 0.5689655172413793
# term2: train 183, test 54, tn 13,fp 14,fn 9,tp 18,precision 0.5625, recall 0.6666666666666666,accuracy 0.5740740740740741, f1-score 0.6101694915254238
# term10: train 392, test 98, tn 31,fp 18,fn 18,tp 31,precision 0.6326530612244898, recall 0.6326530612244898,accuracy 0.6326530612244898, f1-score 0.6326530612244898
# term14: train 34, test 14, tn 1,fp 6,fn 3,tp 4,precision 0.4, recall 0.5714285714285714,accuracy 0.35714285714285715, f1-score 0.47058823529411764
# term4: train 393, test 110, tn 29,fp 26,fn 26,tp 29,precision 0.5272727272727272, recall 0.5272727272727272,accuracy 0.5272727272727272, f1-score 0.5272727272727272
# term18: train 460, test 108, tn 30,fp 24,fn 21,tp 33,precision 0.5789473684210527, recall 0.6111111111111112,accuracy 0.5833333333333334, f1-score 0.5945945945945946
# term6: train 370, test 82, tn 16,fp 25,fn 19,tp 22,precision 0.46808510638297873, recall 0.5365853658536586,accuracy 0.4634146341463415, f1-score 0.5
# term22: train 153, test 46, tn 14,fp 9,fn 9,tp 14,precision 0.6086956521739131, recall 0.6086956521739131,accuracy 0.6086956521739131, f1-score 0.6086956521739131
# term21: train 106, test 40, tn 11,fp 9,fn 8,tp 12,precision 0.5714285714285714, recall 0.6,accuracy 0.575, f1-score 0.5853658536585366
# term20: train 209, test 56, tn 18,fp 10,fn 12,tp 16,precision 0.6153846153846154, recall 0.5714285714285714,accuracy 0.6071428571428571, f1-score 0.5925925925925927
# term12: train 236, test 66, tn 19,fp 14,fn 19,tp 14,precision 0.5, recall 0.42424242424242425,accuracy 0.5, f1-score 0.4590163934426229
# term5: train 404, test 124, tn 32,fp 30,fn 32,tp 30,precision 0.5, recall 0.4838709677419355,accuracy 0.5, f1-score 0.4918032786885246
# term15: train 757, test 190, tn 42,fp 53,fn 42,tp 53,precision 0.5, recall 0.5578947368421052,accuracy 0.5, f1-score 0.5273631840796019
# term16: train 1004, test 242, tn 51,fp 70,fn 51,tp 70,precision 0.5, recall 0.5785123966942148,accuracy 0.5, f1-score 0.5363984674329503
# term1: train 384, test 92, tn 22,fp 24,fn 22,tp 24,precision 0.5, recall 0.5217391304347826,accuracy 0.5, f1-score 0.5106382978723404
# term11: train 600, test 134, tn 45,fp 22,fn 45,tp 22,precision 0.5, recall 0.3283582089552239,accuracy 0.5, f1-score 0.3963963963963964
# term8: train 637, test 156, tn 30,fp 48,fn 30,tp 48,precision 0.5, recall 0.6153846153846154,accuracy 0.5, f1-score 0.5517241379310345
# term0: train 185, test 52, tn 15,fp 11,fn 15,tp 11,precision 0.5, recall 0.4230769230769231,accuracy 0.5, f1-score 0.4583333333333333
# term13: train 367, test 64, tn 16,fp 16,fn 16,tp 16,precision 0.5, recall 0.5,accuracy 0.5, f1-score 0.5
# term17: train 320, test 70, tn 16,fp 19,fn 16,tp 19,precision 0.5, recall 0.5428571428571428,accuracy 0.5, f1-score 0.5205479452054795
# term3: train 299, test 90, tn 20,fp 25,fn 20,tp 25,precision 0.5, recall 0.5555555555555556,accuracy 0.5, f1-score 0.5263157894736842
# term7: train 663, test 142, tn 35,fp 36,fn 35,tp 36,precision 0.5, recall 0.5070422535211268,accuracy 0.5, f1-score 0.5034965034965035
# term9: train 370, test 106, tn 25,fp 28,fn 25,tp 28,precision 0.5, recall 0.5283018867924528,accuracy 0.5, f1-score 0.5137614678899083
# term2: train 183, test 54, tn 8,fp 19,fn 8,tp 19,precision 0.5, recall 0.7037037037037037,accuracy 0.5, f1-score 0.5846153846153846
# term10: train 392, test 98, tn 27,fp 22,fn 27,tp 22,precision 0.5, recall 0.4489795918367347,accuracy 0.5, f1-score 0.47311827956989244
# term14: train 34, test 14, tn 5,fp 2,fn 5,tp 2,precision 0.5, recall 0.2857142857142857,accuracy 0.5, f1-score 0.36363636363636365
# term4: train 393, test 110, tn 30,fp 25,fn 30,tp 25,precision 0.5, recall 0.45454545454545453,accuracy 0.5, f1-score 0.47619047619047616
# term18: train 460, test 108, tn 28,fp 26,fn 28,tp 26,precision 0.5, recall 0.48148148148148145,accuracy 0.5, f1-score 0.49056603773584906
# term6: train 370, test 82, tn 25,fp 16,fn 25,tp 16,precision 0.5, recall 0.3902439024390244,accuracy 0.5, f1-score 0.4383561643835617
# term22: train 153, test 46, tn 8,fp 15,fn 8,tp 15,precision 0.5, recall 0.6521739130434783,accuracy 0.5, f1-score 0.5660377358490566
# term21: train 106, test 40, tn 8,fp 12,fn 8,tp 12,precision 0.5, recall 0.6,accuracy 0.5, f1-score 0.5454545454545454
# term20: train 209, test 56, tn 17,fp 11,fn 17,tp 11,precision 0.5, recall 0.39285714285714285,accuracy 0.5, f1-score 0.44
# term12: train 236, test 66, tn 19,fp 14,fn 19,tp 14,precision 0.5, recall 0.42424242424242425,accuracy 0.5, f1-score 0.4590163934426229
# term5: train 404, test 124, tn 30,fp 32,fn 34,tp 28,precision 0.4666666666666667, recall 0.45161290322580644,accuracy 0.46774193548387094, f1-score 0.45901639344262296
# term15: train 757, test 190, tn 45,fp 50,fn 51,tp 44,precision 0.46808510638297873, recall 0.4631578947368421,accuracy 0.46842105263157896, f1-score 0.46560846560846564
# term16: train 1004, test 242, tn 42,fp 79,fn 68,tp 53,precision 0.4015151515151515, recall 0.4380165289256198,accuracy 0.3925619834710744, f1-score 0.4189723320158103
# term1: train 384, test 92, tn 22,fp 24,fn 27,tp 19,precision 0.4418604651162791, recall 0.41304347826086957,accuracy 0.44565217391304346, f1-score 0.4269662921348315
# term11: train 600, test 134, tn 32,fp 35,fn 38,tp 29,precision 0.453125, recall 0.43283582089552236,accuracy 0.4552238805970149, f1-score 0.44274809160305345
# term8: train 637, test 156, tn 31,fp 47,fn 47,tp 31,precision 0.3974358974358974, recall 0.3974358974358974,accuracy 0.3974358974358974, f1-score 0.3974358974358974
# term0: train 185, test 52, tn 12,fp 14,fn 15,tp 11,precision 0.44, recall 0.4230769230769231,accuracy 0.4423076923076923, f1-score 0.4313725490196078
# term13: train 367, test 64, tn 13,fp 19,fn 22,tp 10,precision 0.3448275862068966, recall 0.3125,accuracy 0.359375, f1-score 0.3278688524590164
# term17: train 320, test 70, tn 12,fp 23,fn 22,tp 13,precision 0.3611111111111111, recall 0.37142857142857144,accuracy 0.35714285714285715, f1-score 0.3661971830985915
# term3: train 299, test 90, tn 21,fp 24,fn 24,tp 21,precision 0.4666666666666667, recall 0.4666666666666667,accuracy 0.4666666666666667, f1-score 0.4666666666666667
# term7: train 663, test 142, tn 37,fp 34,fn 37,tp 34,precision 0.5, recall 0.4788732394366197,accuracy 0.5, f1-score 0.48920863309352514
# term9: train 370, test 106, tn 24,fp 29,fn 32,tp 21,precision 0.42, recall 0.39622641509433965,accuracy 0.42452830188679247, f1-score 0.4077669902912621
# term2: train 183, test 54, tn 12,fp 15,fn 14,tp 13,precision 0.4642857142857143, recall 0.48148148148148145,accuracy 0.46296296296296297, f1-score 0.4727272727272727
# term10: train 392, test 98, tn 20,fp 29,fn 24,tp 25,precision 0.46296296296296297, recall 0.5102040816326531,accuracy 0.45918367346938777, f1-score 0.48543689320388356
# term14: train 34, test 14, tn 3,fp 4,fn 4,tp 3,precision 0.42857142857142855, recall 0.42857142857142855,accuracy 0.42857142857142855, f1-score 0.42857142857142855
# term4: train 393, test 110, tn 22,fp 33,fn 30,tp 25,precision 0.43103448275862066, recall 0.45454545454545453,accuracy 0.42727272727272725, f1-score 0.44247787610619466
# term18: train 460, test 108, tn 23,fp 31,fn 28,tp 26,precision 0.45614035087719296, recall 0.48148148148148145,accuracy 0.4537037037037037, f1-score 0.46846846846846846
# term6: train 370, test 82, tn 10,fp 31,fn 25,tp 16,precision 0.3404255319148936, recall 0.3902439024390244,accuracy 0.3170731707317073, f1-score 0.36363636363636365
# term22: train 153, test 46, tn 12,fp 11,fn 11,tp 12,precision 0.5217391304347826, recall 0.5217391304347826,accuracy 0.5217391304347826, f1-score 0.5217391304347826
# term21: train 106, test 40, tn 10,fp 10,fn 9,tp 11,precision 0.5238095238095238, recall 0.55,accuracy 0.525, f1-score 0.5365853658536585
# term20: train 209, test 56, tn 19,fp 9,fn 14,tp 14,precision 0.6086956521739131, recall 0.5,accuracy 0.5892857142857143, f1-score 0.5490196078431373
# term12: train 236, test 66, tn 22,fp 11,fn 22,tp 11,precision 0.5, recall 0.3333333333333333,accuracy 0.5, f1-score 0.4
# term5: train 404, test 124, tn 38,fp 24,fn 38,tp 24,precision 0.5, recall 0.3870967741935484,accuracy 0.5, f1-score 0.43636363636363634
# term15: train 757, test 190, tn 60,fp 35,fn 60,tp 35,precision 0.5, recall 0.3684210526315789,accuracy 0.5, f1-score 0.4242424242424242
# term16: train 1004, test 242, tn 73,fp 48,fn 73,tp 48,precision 0.5, recall 0.39669421487603307,accuracy 0.5, f1-score 0.4423963133640553
# term1: train 384, test 92, tn 26,fp 20,fn 26,tp 20,precision 0.5, recall 0.43478260869565216,accuracy 0.5, f1-score 0.46511627906976744
# term11: train 600, test 134, tn 41,fp 26,fn 41,tp 26,precision 0.5, recall 0.3880597014925373,accuracy 0.5, f1-score 0.4369747899159664
# term8: train 637, test 156, tn 52,fp 26,fn 52,tp 26,precision 0.5, recall 0.3333333333333333,accuracy 0.5, f1-score 0.4
# term0: train 185, test 52, tn 10,fp 16,fn 10,tp 16,precision 0.5, recall 0.6153846153846154,accuracy 0.5, f1-score 0.5517241379310345
# term13: train 367, test 64, tn 21,fp 11,fn 21,tp 11,precision 0.5, recall 0.34375,accuracy 0.5, f1-score 0.4074074074074074
# term17: train 320, test 70, tn 19,fp 16,fn 19,tp 16,precision 0.5, recall 0.45714285714285713,accuracy 0.5, f1-score 0.4776119402985075
# term3: train 299, test 90, tn 26,fp 19,fn 26,tp 19,precision 0.5, recall 0.4222222222222222,accuracy 0.5, f1-score 0.4578313253012048
# term7: train 663, test 142, tn 41,fp 30,fn 41,tp 30,precision 0.5, recall 0.4225352112676056,accuracy 0.5, f1-score 0.4580152671755725
# term9: train 370, test 106, tn 30,fp 23,fn 30,tp 23,precision 0.5, recall 0.4339622641509434,accuracy 0.5, f1-score 0.46464646464646464
# term2: train 183, test 54, tn 19,fp 8,fn 19,tp 8,precision 0.5, recall 0.2962962962962963,accuracy 0.5, f1-score 0.37209302325581395
# term10: train 392, test 98, tn 24,fp 25,fn 24,tp 25,precision 0.5, recall 0.5102040816326531,accuracy 0.5, f1-score 0.5050505050505051
# term14: train 34, test 14, tn 6,fp 1,fn 6,tp 1,precision 0.5, recall 0.14285714285714285,accuracy 0.5, f1-score 0.22222222222222224
# term4: train 393, test 110, tn 34,fp 21,fn 34,tp 21,precision 0.5, recall 0.38181818181818183,accuracy 0.5, f1-score 0.4329896907216495
# term18: train 460, test 108, tn 37,fp 17,fn 37,tp 17,precision 0.5, recall 0.3148148148148148,accuracy 0.5, f1-score 0.38636363636363635
# term6: train 370, test 82, tn 24,fp 17,fn 24,tp 17,precision 0.5, recall 0.4146341463414634,accuracy 0.5, f1-score 0.45333333333333337
# term22: train 153, test 46, tn 13,fp 10,fn 13,tp 10,precision 0.5, recall 0.43478260869565216,accuracy 0.5, f1-score 0.46511627906976744
# term21: train 106, test 40, tn 13,fp 7,fn 13,tp 7,precision 0.5, recall 0.35,accuracy 0.5, f1-score 0.4117647058823529
# term20: train 209, test 56, tn 15,fp 13,fn 15,tp 13,precision 0.5, recall 0.4642857142857143,accuracy 0.5, f1-score 0.4814814814814815
# term12: train 236, test 66, tn 20,fp 13,fn 14,tp 19,precision 0.59375, recall 0.5757575757575758,accuracy 0.5909090909090909, f1-score 0.5846153846153846
# term5: train 404, test 124, tn 30,fp 32,fn 25,tp 37,precision 0.5362318840579711, recall 0.5967741935483871,accuracy 0.5403225806451613, f1-score 0.5648854961832062
# term15: train 757, test 190, tn 51,fp 44,fn 43,tp 52,precision 0.5416666666666666, recall 0.5473684210526316,accuracy 0.5421052631578948, f1-score 0.544502617801047
# term16: train 1004, test 242, tn 77,fp 44,fn 60,tp 61,precision 0.580952380952381, recall 0.5041322314049587,accuracy 0.5702479338842975, f1-score 0.5398230088495575
# term1: train 384, test 92, tn 20,fp 26,fn 23,tp 23,precision 0.46938775510204084, recall 0.5,accuracy 0.4673913043478261, f1-score 0.4842105263157895
# term11: train 600, test 134, tn 36,fp 31,fn 38,tp 29,precision 0.48333333333333334, recall 0.43283582089552236,accuracy 0.48507462686567165, f1-score 0.45669291338582674
# term8: train 637, test 156, tn 30,fp 48,fn 36,tp 42,precision 0.4666666666666667, recall 0.5384615384615384,accuracy 0.46153846153846156, f1-score 0.5
# term0: train 185, test 52, tn 15,fp 11,fn 13,tp 13,precision 0.5416666666666666, recall 0.5,accuracy 0.5384615384615384, f1-score 0.52
# term13: train 367, test 64, tn 22,fp 10,fn 18,tp 14,precision 0.5833333333333334, recall 0.4375,accuracy 0.5625, f1-score 0.5
# term17: train 320, test 70, tn 14,fp 21,fn 14,tp 21,precision 0.5, recall 0.6,accuracy 0.5, f1-score 0.5454545454545454
# term3: train 299, test 90, tn 29,fp 16,fn 21,tp 24,precision 0.6, recall 0.5333333333333333,accuracy 0.5888888888888889, f1-score 0.5647058823529412
# term7: train 663, test 142, tn 33,fp 38,fn 39,tp 32,precision 0.45714285714285713, recall 0.4507042253521127,accuracy 0.45774647887323944, f1-score 0.45390070921985815
# term9: train 370, test 106, tn 25,fp 28,fn 19,tp 34,precision 0.5483870967741935, recall 0.6415094339622641,accuracy 0.5566037735849056, f1-score 0.591304347826087
# term2: train 183, test 54, tn 13,fp 14,fn 17,tp 10,precision 0.4166666666666667, recall 0.37037037037037035,accuracy 0.42592592592592593, f1-score 0.39215686274509803
# term10: train 392, test 98, tn 25,fp 24,fn 33,tp 16,precision 0.4, recall 0.32653061224489793,accuracy 0.41836734693877553, f1-score 0.35955056179775274
# term14: train 34, test 14, tn 6,fp 1,fn 4,tp 3,precision 0.75, recall 0.42857142857142855,accuracy 0.6428571428571429, f1-score 0.5454545454545454
# term4: train 393, test 110, tn 28,fp 27,fn 26,tp 29,precision 0.5178571428571429, recall 0.5272727272727272,accuracy 0.5181818181818182, f1-score 0.5225225225225225
# term18: train 460, test 108, tn 20,fp 34,fn 26,tp 28,precision 0.45161290322580644, recall 0.5185185185185185,accuracy 0.4444444444444444, f1-score 0.48275862068965514
# term6: train 370, test 82, tn 26,fp 15,fn 24,tp 17,precision 0.53125, recall 0.4146341463414634,accuracy 0.524390243902439, f1-score 0.4657534246575343
# term22: train 153, test 46, tn 9,fp 14,fn 10,tp 13,precision 0.48148148148148145, recall 0.5652173913043478,accuracy 0.4782608695652174, f1-score 0.52
# term21: train 106, test 40, tn 13,fp 7,fn 7,tp 13,precision 0.65, recall 0.65,accuracy 0.65, f1-score 0.65
# term20: train 209, test 56, tn 13,fp 15,fn 21,tp 7,precision 0.3181818181818182, recall 0.25,accuracy 0.35714285714285715, f1-score 0.28
# [('f0', 0.5250463821892394),
#  ('f1', 0.5650821856952465),
#  ('f2', 0.5046382189239332),
#  ('f3', 0.4424695977549112),
#  ('f4', 0.44258872651356995),
#  ('f5', 0.5070821529745042)]

# %%
best_feature,score = max(threshold_score,key=lambda x:x[1])
best_feature,score
# Out:
# ('f1', 0.5650821856952465)

# %%
baseline_test = []
for r in rel_test.keys():
    res = get_threshold_score(r,df_train,df_test,best_feature)
    print("{}: train {}, test {}, precision {}, recall {},accuracy {}, f1-score {}"
          .format(r,res['train'],res['test'],res['precision'],res['recall'],res['accuracy'],res['F1']))
    baseline_test.append(res)
# Out:
# term21: train 106, test 32, precision 0.6875, recall 0.6875,accuracy 0.6875, f1-score 0.6875
# term11: train 600, test 144, precision 0.5119047619047619, recall 0.5972222222222222,accuracy 0.5138888888888888, f1-score 0.5512820512820512
# term7: train 663, test 166, precision 0.5529411764705883, recall 0.5662650602409639,accuracy 0.5542168674698795, f1-score 0.5595238095238094
# term10: train 392, test 128, precision 0.5492957746478874, recall 0.609375,accuracy 0.5546875, f1-score 0.5777777777777777
# term18: train 460, test 110, precision 0.53125, recall 0.6181818181818182,accuracy 0.5363636363636364, f1-score 0.5714285714285714
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# term6: train 370, test 84, precision 0.5098039215686274, recall 0.6190476190476191,accuracy 0.5119047619047619, f1-score 0.5591397849462365
# term8: train 637, test 180, precision 0.47474747474747475, recall 0.5222222222222223,accuracy 0.4722222222222222, f1-score 0.4973544973544973
# term12: train 236, test 60, precision 0.5, recall 0.6333333333333333,accuracy 0.5, f1-score 0.5588235294117647
# term15: train 757, test 182, precision 0.4528301886792453, recall 0.5274725274725275,accuracy 0.44505494505494503, f1-score 0.4873096446700508
# term5: train 404, test 84, precision 0.5348837209302325, recall 0.5476190476190477,accuracy 0.5357142857142857, f1-score 0.5411764705882354
# term16: train 1004, test 262, precision 0.45806451612903226, recall 0.5419847328244275,accuracy 0.45038167938931295, f1-score 0.49650349650349646
# term17: train 320, test 74, precision 0.6136363636363636, recall 0.7297297297297297,accuracy 0.6351351351351351, f1-score 0.6666666666666666
# term1: train 384, test 118, precision 0.4794520547945205, recall 0.5932203389830508,accuracy 0.4745762711864407, f1-score 0.5303030303030303
# term3: train 299, test 70, precision 0.5227272727272727, recall 0.6571428571428571,accuracy 0.5285714285714286, f1-score 0.5822784810126581
# term20: train 209, test 70, precision 0.5142857142857142, recall 0.5142857142857142,accuracy 0.5142857142857142, f1-score 0.5142857142857142
# term2: train 183, test 42, precision 0.5, recall 0.5238095238095238,accuracy 0.5, f1-score 0.5116279069767442
# term0: train 185, test 34, precision 0.45, recall 0.5294117647058824,accuracy 0.4411764705882353, f1-score 0.48648648648648646
# term13: train 367, test 96, precision 0.5581395348837209, recall 0.5,accuracy 0.5520833333333334, f1-score 0.5274725274725274
# term4: train 393, test 90, precision 0.4909090909090909, recall 0.6,accuracy 0.4888888888888889, f1-score 0.54
# term22: train 153, test 34, precision 0.46153846153846156, recall 0.35294117647058826,accuracy 0.47058823529411764, f1-score 0.4000000000000001
# term9: train 370, test 78, precision 0.5348837209302325, recall 0.5897435897435898,accuracy 0.5384615384615384, f1-score 0.5609756097560975
# term14: train 34, test 4, precision 0.5, recall 1.0,accuracy 0.5, f1-score 0.6666666666666666
# term19: train 10, test 6, precision 0.5, recall 0.6666666666666666,accuracy 0.5, f1-score 0.5714285714285715

# %%
pd.DataFrame(baseline_test).mean()
# Out:
# train        371.130435
# test          93.391304
# tn            20.739130
# fp            25.956522
# fn            19.956522
# tp            26.739130
# precision      0.516904
# recall         0.596834
# accuracy       0.517639
# F1             0.549827
# dtype: float64

# %%
print('Test F1-score: {}'.format(computeF1(pd.DataFrame(baseline_test))))
# Out:
# Test F1-score: 0.5380577427821522

# %% [markdown]
# ## 2) Train and test a classifier for each relation

# %% [markdown]
# ### Train with grid search on validation set

# %%
from sklearn.model_selection import ParameterGrid
param_grid = {
    'max_depth': [20,40,60,80],
    'n_estimators': [50,100, 200]
}
list(ParameterGrid(param_grid))
# Out:
# [{'max_depth': 20, 'n_estimators': 50},
#  {'max_depth': 20, 'n_estimators': 100},
#  {'max_depth': 20, 'n_estimators': 200},
#  {'max_depth': 40, 'n_estimators': 50},
#  {'max_depth': 40, 'n_estimators': 100},
#  {'max_depth': 40, 'n_estimators': 200},
#  {'max_depth': 60, 'n_estimators': 50},
#  {'max_depth': 60, 'n_estimators': 100},
#  {'max_depth': 60, 'n_estimators': 200},
#  {'max_depth': 80, 'n_estimators': 50},
#  {'max_depth': 80, 'n_estimators': 100},
#  {'max_depth': 80, 'n_estimators': 200}]

# %%
def train_model_parameter(r,df_train,df_validation,param):
    print(param)
    y_train = df_train[df_train.relation==r]['label']
    X_train = df_train[df_train.relation==r][['f0','f1','f2','f3','f4','f5']]
    y_validation = df_validation[df_validation.relation==r]['label']
    X_validation = df_validation[df_validation.relation==r][['f0','f1','f2','f3','f4','f5']]
    model = RandomForestClassifier(**param, random_state=42)
    model.fit(X_train, y_train)
    pred_validation = model.predict_proba(X_validation)
    pred_class_validation = model.predict(X_validation)
    fpr, tpr, thresholds = metrics.roc_curve(y_validation, pred_validation[:,0], pos_label=1)
    tn, fp, fn, tp = metrics.confusion_matrix(y_validation,pred_class_validation).ravel()
    return {'train':y_train.shape[0],'test':y_validation.shape[0],
            'tn':tn,'fp':fp,'fn':fn,'tp':tp,
            'AUC':metrics.auc(fpr, tpr),'precision':metrics.precision_score(y_validation,pred_class_validation),
            'recall':metrics.recall_score(y_validation,pred_class_validation),
            'accuracy':metrics.accuracy_score(y_validation,pred_class_validation),
            'F1':metrics.f1_score(y_validation,pred_class_validation)}

# %% [markdown]
# We perform a grid search in orderto find the best paramters for the Random forest model.
#
# It is also possibile to select a set of parameters for each model and to explore different classification models (e.g. gradient boosting).

# %%
score_param = []
for param in list(ParameterGrid(param_grid)):
    auc_validation = []
    for r in rel_validation.keys():
        res = train_model_parameter(r,df_train,df_validation,param)
        print("{}: train {}, test {}, auc {}, precision {},recall {}, accuracy {}, f1-score {}"
              .format(r,res['train'],res['test'],res['AUC'],res['precision'],res['recall'],res['accuracy'],res['F1']))
        auc_validation.append(res)
    f1 = pd.DataFrame(auc_validation).mean()['F1']
    score_param.append((param,f1))
score_param
# Out:
# {'max_depth': 20, 'n_estimators': 50}
# term12: train 472, test 66, auc 0.12626262626262624, precision 0.7435897435897436,recall 0.8787878787878788, accuracy 0.7878787878787878, f1-score 0.8055555555555556
# {'max_depth': 20, 'n_estimators': 50}
# term5: train 808, test 124, auc 0.1757284079084287, precision 0.7313432835820896,recall 0.7903225806451613, accuracy 0.75, f1-score 0.7596899224806203
# {'max_depth': 20, 'n_estimators': 50}
# term15: train 1514, test 190, auc 0.38764542936288093, precision 0.5652173913043478,recall 0.8210526315789474, accuracy 0.5947368421052631, f1-score 0.6695278969957081
# {'max_depth': 20, 'n_estimators': 50}
# term16: train 1004, test 242, auc 0.5, precision 0.5,recall 1.0, accuracy 0.5, f1-score 0.6666666666666666
# {'max_depth': 20, 'n_estimators': 50}
# term1: train 768, test 92, auc 0.5278827977315691, precision 0.5063291139240507,recall 0.8695652173913043, accuracy 0.5108695652173914, f1-score 0.6400000000000001
# {'max_depth': 20, 'n_estimators': 50}
# term11: train 1200, test 134, auc 0.5552461572733348, precision 0.5175438596491229,recall 0.8805970149253731, accuracy 0.5298507462686567, f1-score 0.6519337016574586
# {'max_depth': 20, 'n_estimators': 50}
# term8: train 1274, test 156, auc 0.14677843523997372, precision 0.8076923076923077,recall 0.8076923076923077, accuracy 0.8076923076923077, f1-score 0.8076923076923077
# {'max_depth': 20, 'n_estimators': 50}
# term0: train 370, test 52, auc 0.3239644970414201, precision 0.5294117647058824,recall 0.6923076923076923, accuracy 0.5384615384615384, f1-score 0.5999999999999999
# {'max_depth': 20, 'n_estimators': 50}
# term13: train 734, test 64, auc 0.35791015625, precision 0.6153846153846154,recall 0.75, accuracy 0.640625, f1-score 0.676056338028169
# {'max_depth': 20, 'n_estimators': 50}
# term17: train 640, test 70, auc 0.48408163265306126, precision 0.5614035087719298,recall 0.9142857142857143, accuracy 0.6, f1-score 0.6956521739130436
# {'max_depth': 20, 'n_estimators': 50}
# term3: train 598, test 90, auc 0.38814814814814813, precision 0.5161290322580645,recall 0.7111111111111111, accuracy 0.5222222222222223, f1-score 0.5981308411214953
# {'max_depth': 20, 'n_estimators': 50}
# term7: train 1326, test 142, auc 0.1442174171791311, precision 0.7469879518072289,recall 0.8732394366197183, accuracy 0.7887323943661971, f1-score 0.8051948051948051
# {'max_depth': 20, 'n_estimators': 50}
# term9: train 740, test 106, auc 0.2185831256674973, precision 0.7755102040816326,recall 0.7169811320754716, accuracy 0.7547169811320755, f1-score 0.7450980392156863
# {'max_depth': 20, 'n_estimators': 50}
# term2: train 366, test 54, auc 0.37379972565157754, precision 0.5806451612903226,recall 0.6666666666666666, accuracy 0.5925925925925926, f1-score 0.6206896551724138
# {'max_depth': 20, 'n_estimators': 50}
# term10: train 784, test 98, auc 0.15181174510620574, precision 0.75,recall 0.9183673469387755, accuracy 0.8061224489795918, f1-score 0.8256880733944955
# {'max_depth': 20, 'n_estimators': 50}
# term14: train 68, test 14, auc 0.4285714285714286, precision 0.5,recall 0.5714285714285714, accuracy 0.5, f1-score 0.5333333333333333
# {'max_depth': 20, 'n_estimators': 50}
# term4: train 786, test 110, auc 0.32644628099173556, precision 0.5357142857142857,recall 0.8181818181818182, accuracy 0.5545454545454546, f1-score 0.6474820143884892
# {'max_depth': 20, 'n_estimators': 50}
# term18: train 920, test 108, auc 0.49039780521262005, precision 0.5051546391752577,recall 0.9074074074074074, accuracy 0.5092592592592593, f1-score 0.6490066225165563
# {'max_depth': 20, 'n_estimators': 50}
# term6: train 740, test 82, auc 0.2034503271861987, precision 0.6923076923076923,recall 0.8780487804878049, accuracy 0.7439024390243902, f1-score 0.7741935483870966
# {'max_depth': 20, 'n_estimators': 50}
# term22: train 306, test 46, auc 0.0992438563327032, precision 0.7727272727272727,recall 0.7391304347826086, accuracy 0.7608695652173914, f1-score 0.7555555555555555
# {'max_depth': 20, 'n_estimators': 50}
# term21: train 212, test 40, auc 0.33749999999999997, precision 0.5454545454545454,recall 0.6, accuracy 0.55, f1-score 0.5714285714285713
# {'max_depth': 20, 'n_estimators': 50}
# term20: train 418, test 56, auc 0.423469387755102, precision 0.5925925925925926,recall 0.5714285714285714, accuracy 0.5892857142857143, f1-score 0.5818181818181818
# {'max_depth': 20, 'n_estimators': 100}
# term12: train 472, test 66, auc 0.12809917355371897, precision 0.75,recall 0.9090909090909091, accuracy 0.803030303030303, f1-score 0.821917808219178
# {'max_depth': 20, 'n_estimators': 100}
# term5: train 808, test 124, auc 0.177939646201873, precision 0.7164179104477612,recall 0.7741935483870968, accuracy 0.7338709677419355, f1-score 0.7441860465116278
# {'max_depth': 20, 'n_estimators': 100}
# term15: train 1514, test 190, auc 0.3809418282548476, precision 0.5571428571428572,recall 0.8210526315789474, accuracy 0.5842105263157895, f1-score 0.6638297872340425
# {'max_depth': 20, 'n_estimators': 100}
# term16: train 1004, test 242, auc 0.5, precision 0.5,recall 1.0, accuracy 0.5, f1-score 0.6666666666666666
# {'max_depth': 20, 'n_estimators': 100}
# term1: train 768, test 92, auc 0.5392249527410208, precision 0.5,recall 0.8478260869565217, accuracy 0.5, f1-score 0.6290322580645161
# {'max_depth': 20, 'n_estimators': 100}
# term11: train 1200, test 134, auc 0.5667186455780797, precision 0.5172413793103449,recall 0.8955223880597015, accuracy 0.5298507462686567, f1-score 0.6557377049180328
# {'max_depth': 20, 'n_estimators': 100}
# term8: train 1274, test 156, auc 0.14291584483892175, precision 0.7804878048780488,recall 0.8205128205128205, accuracy 0.7948717948717948, f1-score 0.8
# {'max_depth': 20, 'n_estimators': 100}
# term0: train 370, test 52, auc 0.3313609467455621, precision 0.5454545454545454,recall 0.6923076923076923, accuracy 0.5576923076923077, f1-score 0.6101694915254238
# {'max_depth': 20, 'n_estimators': 100}
# term13: train 734, test 64, auc 0.3486328125, precision 0.6153846153846154,recall 0.75, accuracy 0.640625, f1-score 0.676056338028169
# {'max_depth': 20, 'n_estimators': 100}
# term17: train 640, test 70, auc 0.4636734693877551, precision 0.5614035087719298,recall 0.9142857142857143, accuracy 0.6, f1-score 0.6956521739130436
# {'max_depth': 20, 'n_estimators': 100}
# term3: train 598, test 90, auc 0.4064197530864197, precision 0.53125,recall 0.7555555555555555, accuracy 0.5444444444444444, f1-score 0.6238532110091743
# {'max_depth': 20, 'n_estimators': 100}
# term7: train 1326, test 142, auc 0.14451497718706607, precision 0.7560975609756098,recall 0.8732394366197183, accuracy 0.795774647887324, f1-score 0.8104575163398693
# {'max_depth': 20, 'n_estimators': 100}
# term9: train 740, test 106, auc 0.22018511925952297, precision 0.78,recall 0.7358490566037735, accuracy 0.7641509433962265, f1-score 0.7572815533980584
# {'max_depth': 20, 'n_estimators': 100}
# term2: train 366, test 54, auc 0.3744855967078189, precision 0.5757575757575758,recall 0.7037037037037037, accuracy 0.5925925925925926, f1-score 0.6333333333333334
# {'max_depth': 20, 'n_estimators': 100}
# term10: train 784, test 98, auc 0.14223240316534777, precision 0.7258064516129032,recall 0.9183673469387755, accuracy 0.7857142857142857, f1-score 0.8108108108108109
# {'max_depth': 20, 'n_estimators': 100}
# term14: train 68, test 14, auc 0.47959183673469385, precision 0.5,recall 0.5714285714285714, accuracy 0.5, f1-score 0.5333333333333333
# {'max_depth': 20, 'n_estimators': 100}
# term4: train 786, test 110, auc 0.3305785123966942, precision 0.5555555555555556,recall 0.8181818181818182, accuracy 0.5818181818181818, f1-score 0.661764705882353
# {'max_depth': 20, 'n_estimators': 100}
# term18: train 920, test 108, auc 0.492283950617284, precision 0.5051546391752577,recall 0.9074074074074074, accuracy 0.5092592592592593, f1-score 0.6490066225165563
# {'max_depth': 20, 'n_estimators': 100}
# term6: train 740, test 82, auc 0.1954193932183224, precision 0.7254901960784313,recall 0.9024390243902439, accuracy 0.7804878048780488, f1-score 0.8043478260869564
# {'max_depth': 20, 'n_estimators': 100}
# term22: train 306, test 46, auc 0.11153119092627599, precision 0.8,recall 0.8695652173913043, accuracy 0.8260869565217391, f1-score 0.8333333333333333
# {'max_depth': 20, 'n_estimators': 100}
# term21: train 212, test 40, auc 0.31875, precision 0.5833333333333334,recall 0.7, accuracy 0.6, f1-score 0.6363636363636365
# {'max_depth': 20, 'n_estimators': 100}
# term20: train 418, test 56, auc 0.4094387755102041, precision 0.5862068965517241,recall 0.6071428571428571, accuracy 0.5892857142857143, f1-score 0.5964912280701754
# {'max_depth': 20, 'n_estimators': 200}
# term12: train 472, test 66, auc 0.1271808999081726, precision 0.725,recall 0.8787878787878788, accuracy 0.7727272727272727, f1-score 0.7945205479452054
# {'max_depth': 20, 'n_estimators': 200}
# term5: train 808, test 124, auc 0.1677939646201873, precision 0.7272727272727273,recall 0.7741935483870968, accuracy 0.7419354838709677, f1-score 0.7500000000000001
# {'max_depth': 20, 'n_estimators': 200}
# term15: train 1514, test 190, auc 0.3809418282548477, precision 0.5563380281690141,recall 0.8315789473684211, accuracy 0.5842105263157895, f1-score 0.6666666666666667
# {'max_depth': 20, 'n_estimators': 200}
# term16: train 1004, test 242, auc 0.5, precision 0.5,recall 1.0, accuracy 0.5, f1-score 0.6666666666666666
# {'max_depth': 20, 'n_estimators': 200}
# term1: train 768, test 92, auc 0.5439508506616257, precision 0.5128205128205128,recall 0.8695652173913043, accuracy 0.5217391304347826, f1-score 0.6451612903225806
# {'max_depth': 20, 'n_estimators': 200}
# term11: train 1200, test 134, auc 0.5623746936957006, precision 0.5172413793103449,recall 0.8955223880597015, accuracy 0.5298507462686567, f1-score 0.6557377049180328
# {'max_depth': 20, 'n_estimators': 200}
# term8: train 1274, test 156, auc 0.14472386587771202, precision 0.7831325301204819,recall 0.8333333333333334, accuracy 0.8012820512820513, f1-score 0.8074534161490683
# {'max_depth': 20, 'n_estimators': 200}
# term0: train 370, test 52, auc 0.3099112426035503, precision 0.5714285714285714,recall 0.7692307692307693, accuracy 0.5961538461538461, f1-score 0.6557377049180327
# {'max_depth': 20, 'n_estimators': 200}
# term13: train 734, test 64, auc 0.361328125, precision 0.6097560975609756,recall 0.78125, accuracy 0.640625, f1-score 0.684931506849315
# {'max_depth': 20, 'n_estimators': 200}
# term17: train 640, test 70, auc 0.46408163265306124, precision 0.5423728813559322,recall 0.9142857142857143, accuracy 0.5714285714285714, f1-score 0.6808510638297872
# {'max_depth': 20, 'n_estimators': 200}
# term3: train 598, test 90, auc 0.39901234567901234, precision 0.5238095238095238,recall 0.7333333333333333, accuracy 0.5333333333333333, f1-score 0.611111111111111
# {'max_depth': 20, 'n_estimators': 200}
# term7: train 1326, test 142, auc 0.1460027772267407, precision 0.7349397590361446,recall 0.8591549295774648, accuracy 0.7746478873239436, f1-score 0.7922077922077921
# {'max_depth': 20, 'n_estimators': 200}
# term9: train 740, test 106, auc 0.21751512993948025, precision 0.803921568627451,recall 0.7735849056603774, accuracy 0.7924528301886793, f1-score 0.7884615384615384
# {'max_depth': 20, 'n_estimators': 200}
# term2: train 366, test 54, auc 0.3786008230452675, precision 0.6129032258064516,recall 0.7037037037037037, accuracy 0.6296296296296297, f1-score 0.6551724137931035
# {'max_depth': 20, 'n_estimators': 200}
# term10: train 784, test 98, auc 0.136609745939192, precision 0.7301587301587301,recall 0.9387755102040817, accuracy 0.7959183673469388, f1-score 0.8214285714285714
# {'max_depth': 20, 'n_estimators': 200}
# term14: train 68, test 14, auc 0.4897959183673469, precision 0.5,recall 0.42857142857142855, accuracy 0.5, f1-score 0.4615384615384615
# {'max_depth': 20, 'n_estimators': 200}
# term4: train 786, test 110, auc 0.3233057851239669, precision 0.5555555555555556,recall 0.8181818181818182, accuracy 0.5818181818181818, f1-score 0.661764705882353
# {'max_depth': 20, 'n_estimators': 200}
# term18: train 920, test 108, auc 0.48954046639231824, precision 0.5051546391752577,recall 0.9074074074074074, accuracy 0.5092592592592593, f1-score 0.6490066225165563
# {'max_depth': 20, 'n_estimators': 200}
# term6: train 740, test 82, auc 0.1977989292088043, precision 0.6923076923076923,recall 0.8780487804878049, accuracy 0.7439024390243902, f1-score 0.7741935483870966
# {'max_depth': 20, 'n_estimators': 200}
# term22: train 306, test 46, auc 0.10302457466918713, precision 0.8,recall 0.8695652173913043, accuracy 0.8260869565217391, f1-score 0.8333333333333333
# {'max_depth': 20, 'n_estimators': 200}
# term21: train 212, test 40, auc 0.30875, precision 0.5925925925925926,recall 0.8, accuracy 0.625, f1-score 0.6808510638297872
# {'max_depth': 20, 'n_estimators': 200}
# term20: train 418, test 56, auc 0.39158163265306123, precision 0.5666666666666667,recall 0.6071428571428571, accuracy 0.5714285714285714, f1-score 0.5862068965517241
# {'max_depth': 40, 'n_estimators': 50}
# term12: train 472, test 66, auc 0.12350780532598712, precision 0.7435897435897436,recall 0.8787878787878788, accuracy 0.7878787878787878, f1-score 0.8055555555555556
# {'max_depth': 40, 'n_estimators': 50}
# term5: train 808, test 124, auc 0.17169614984391257, precision 0.7428571428571429,recall 0.8387096774193549, accuracy 0.7741935483870968, f1-score 0.787878787878788
# {'max_depth': 40, 'n_estimators': 50}
# term15: train 1514, test 190, auc 0.3905817174515236, precision 0.5639097744360902,recall 0.7894736842105263, accuracy 0.5894736842105263, f1-score 0.6578947368421052
# {'max_depth': 40, 'n_estimators': 50}
# term16: train 1004, test 242, auc 0.5, precision 0.5,recall 1.0, accuracy 0.5, f1-score 0.6666666666666666
# {'max_depth': 40, 'n_estimators': 50}
# term1: train 768, test 92, auc 0.5366257088846881, precision 0.5128205128205128,recall 0.8695652173913043, accuracy 0.5217391304347826, f1-score 0.6451612903225806
# {'max_depth': 40, 'n_estimators': 50}
# term11: train 1200, test 134, auc 0.5549120071285365, precision 0.5087719298245614,recall 0.8656716417910447, accuracy 0.5149253731343284, f1-score 0.6408839779005525
# {'max_depth': 40, 'n_estimators': 50}
# term8: train 1274, test 156, auc 0.15310650887573962, precision 0.7848101265822784,recall 0.7948717948717948, accuracy 0.7884615384615384, f1-score 0.7898089171974522
# {'max_depth': 40, 'n_estimators': 50}
# term0: train 370, test 52, auc 0.3239644970414201, precision 0.5294117647058824,recall 0.6923076923076923, accuracy 0.5384615384615384, f1-score 0.5999999999999999
# {'max_depth': 40, 'n_estimators': 50}
# term13: train 734, test 64, auc 0.361328125, precision 0.6216216216216216,recall 0.71875, accuracy 0.640625, f1-score 0.6666666666666667
# {'max_depth': 40, 'n_estimators': 50}
# term17: train 640, test 70, auc 0.4889795918367347, precision 0.5614035087719298,recall 0.9142857142857143, accuracy 0.6, f1-score 0.6956521739130436
# {'max_depth': 40, 'n_estimators': 50}
# term3: train 598, test 90, auc 0.39555555555555555, precision 0.5161290322580645,recall 0.7111111111111111, accuracy 0.5222222222222223, f1-score 0.5981308411214953
# {'max_depth': 40, 'n_estimators': 50}
# term7: train 1326, test 142, auc 0.13608411029557627, precision 0.7407407407407407,recall 0.8450704225352113, accuracy 0.7746478873239436, f1-score 0.7894736842105262
# {'max_depth': 40, 'n_estimators': 50}
# term9: train 740, test 106, auc 0.21947312210751155, precision 0.7959183673469388,recall 0.7358490566037735, accuracy 0.7735849056603774, f1-score 0.7647058823529412
# {'max_depth': 40, 'n_estimators': 50}
# term2: train 366, test 54, auc 0.3779149519890261, precision 0.5806451612903226,recall 0.6666666666666666, accuracy 0.5925925925925926, f1-score 0.6206896551724138
# {'max_depth': 40, 'n_estimators': 50}
# term10: train 784, test 98, auc 0.14972927946688877, precision 0.7666666666666667,recall 0.9387755102040817, accuracy 0.826530612244898, f1-score 0.8440366972477065
# {'max_depth': 40, 'n_estimators': 50}
# term14: train 68, test 14, auc 0.4285714285714286, precision 0.5,recall 0.5714285714285714, accuracy 0.5, f1-score 0.5333333333333333
# {'max_depth': 40, 'n_estimators': 50}
# term4: train 786, test 110, auc 0.3239669421487604, precision 0.5357142857142857,recall 0.8181818181818182, accuracy 0.5545454545454546, f1-score 0.6474820143884892
# {'max_depth': 40, 'n_estimators': 50}
# term18: train 920, test 108, auc 0.49417009602194795, precision 0.5051546391752577,recall 0.9074074074074074, accuracy 0.5092592592592593, f1-score 0.6490066225165563
# {'max_depth': 40, 'n_estimators': 50}
# term6: train 740, test 82, auc 0.2046400951814396, precision 0.68,recall 0.8292682926829268, accuracy 0.7195121951219512, f1-score 0.7472527472527474
# {'max_depth': 40, 'n_estimators': 50}
# term22: train 306, test 46, auc 0.0992438563327032, precision 0.7727272727272727,recall 0.7391304347826086, accuracy 0.7608695652173914, f1-score 0.7555555555555555
# {'max_depth': 40, 'n_estimators': 50}
# term21: train 212, test 40, auc 0.33375000000000005, precision 0.5454545454545454,recall 0.6, accuracy 0.55, f1-score 0.5714285714285713
# {'max_depth': 40, 'n_estimators': 50}
# term20: train 418, test 56, auc 0.42538265306122447, precision 0.6071428571428571,recall 0.6071428571428571, accuracy 0.6071428571428571, f1-score 0.6071428571428571
# {'max_depth': 40, 'n_estimators': 100}
# term12: train 472, test 66, auc 0.12672176308539942, precision 0.75,recall 0.9090909090909091, accuracy 0.803030303030303, f1-score 0.821917808219178
# {'max_depth': 40, 'n_estimators': 100}
# term5: train 808, test 124, auc 0.1750780437044745, precision 0.7205882352941176,recall 0.7903225806451613, accuracy 0.7419354838709677, f1-score 0.7538461538461538
# {'max_depth': 40, 'n_estimators': 100}
# term15: train 1514, test 190, auc 0.3914127423822714, precision 0.5579710144927537,recall 0.8105263157894737, accuracy 0.5842105263157895, f1-score 0.6609442060085836
# {'max_depth': 40, 'n_estimators': 100}
# term16: train 1004, test 242, auc 0.5, precision 0.5,recall 1.0, accuracy 0.5, f1-score 0.6666666666666666
# {'max_depth': 40, 'n_estimators': 100}
# term1: train 768, test 92, auc 0.5446597353497165, precision 0.5064935064935064,recall 0.8478260869565217, accuracy 0.5108695652173914, f1-score 0.6341463414634146
# {'max_depth': 40, 'n_estimators': 100}
# term11: train 1200, test 134, auc 0.5732902650924482, precision 0.5172413793103449,recall 0.8955223880597015, accuracy 0.5298507462686567, f1-score 0.6557377049180328
# {'max_depth': 40, 'n_estimators': 100}
# term8: train 1274, test 156, auc 0.15014792899408286, precision 0.7777777777777778,recall 0.8076923076923077, accuracy 0.7884615384615384, f1-score 0.7924528301886792
# {'max_depth': 40, 'n_estimators': 100}
# term0: train 370, test 52, auc 0.3313609467455621, precision 0.5454545454545454,recall 0.6923076923076923, accuracy 0.5576923076923077, f1-score 0.6101694915254238
# {'max_depth': 40, 'n_estimators': 100}
# term13: train 734, test 64, auc 0.35888671875, precision 0.6153846153846154,recall 0.75, accuracy 0.640625, f1-score 0.676056338028169
# {'max_depth': 40, 'n_estimators': 100}
# term17: train 640, test 70, auc 0.46571428571428564, precision 0.5614035087719298,recall 0.9142857142857143, accuracy 0.6, f1-score 0.6956521739130436
# {'max_depth': 40, 'n_estimators': 100}
# term3: train 598, test 90, auc 0.4098765432098765, precision 0.5238095238095238,recall 0.7333333333333333, accuracy 0.5333333333333333, f1-score 0.611111111111111
# {'max_depth': 40, 'n_estimators': 100}
# term7: train 1326, test 142, auc 0.13717516365800436, precision 0.7349397590361446,recall 0.8591549295774648, accuracy 0.7746478873239436, f1-score 0.7922077922077921
# {'max_depth': 40, 'n_estimators': 100}
# term9: train 740, test 106, auc 0.2207191171235315, precision 0.7916666666666666,recall 0.7169811320754716, accuracy 0.7641509433962265, f1-score 0.7524752475247525
# {'max_depth': 40, 'n_estimators': 100}
# term2: train 366, test 54, auc 0.37448559670781895, precision 0.5757575757575758,recall 0.7037037037037037, accuracy 0.5925925925925926, f1-score 0.6333333333333334
# {'max_depth': 40, 'n_estimators': 100}
# term10: train 784, test 98, auc 0.1364014993752603, precision 0.75,recall 0.9183673469387755, accuracy 0.8061224489795918, f1-score 0.8256880733944955
# {'max_depth': 40, 'n_estimators': 100}
# term14: train 68, test 14, auc 0.47959183673469385, precision 0.5,recall 0.5714285714285714, accuracy 0.5, f1-score 0.5333333333333333
# {'max_depth': 40, 'n_estimators': 100}
# term4: train 786, test 110, auc 0.32727272727272727, precision 0.5609756097560976,recall 0.8363636363636363, accuracy 0.5909090909090909, f1-score 0.6715328467153284
# {'max_depth': 40, 'n_estimators': 100}
# term18: train 920, test 108, auc 0.4922839506172839, precision 0.5051546391752577,recall 0.9074074074074074, accuracy 0.5092592592592593, f1-score 0.6490066225165563
# {'max_depth': 40, 'n_estimators': 100}
# term6: train 740, test 82, auc 0.19928613920285543, precision 0.72,recall 0.8780487804878049, accuracy 0.7682926829268293, f1-score 0.7912087912087912
# {'max_depth': 40, 'n_estimators': 100}
# term22: train 306, test 46, auc 0.11153119092627599, precision 0.8,recall 0.8695652173913043, accuracy 0.8260869565217391, f1-score 0.8333333333333333
# {'max_depth': 40, 'n_estimators': 100}
# term21: train 212, test 40, auc 0.3175, precision 0.5833333333333334,recall 0.7, accuracy 0.6, f1-score 0.6363636363636365
# {'max_depth': 40, 'n_estimators': 100}
# term20: train 418, test 56, auc 0.4113520408163265, precision 0.5862068965517241,recall 0.6071428571428571, accuracy 0.5892857142857143, f1-score 0.5964912280701754
# {'max_depth': 40, 'n_estimators': 200}
# term12: train 472, test 66, auc 0.1271808999081726, precision 0.725,recall 0.8787878787878788, accuracy 0.7727272727272727, f1-score 0.7945205479452054
# {'max_depth': 40, 'n_estimators': 200}
# term5: train 808, test 124, auc 0.16298126951092612, precision 0.7272727272727273,recall 0.7741935483870968, accuracy 0.7419354838709677, f1-score 0.7500000000000001
# {'max_depth': 40, 'n_estimators': 200}
# term15: train 1514, test 190, auc 0.39002770083102495, precision 0.5664335664335665,recall 0.8526315789473684, accuracy 0.6, f1-score 0.680672268907563
# {'max_depth': 40, 'n_estimators': 200}
# term16: train 1004, test 242, auc 0.5, precision 0.5,recall 1.0, accuracy 0.5, f1-score 0.6666666666666666
# {'max_depth': 40, 'n_estimators': 200}
# term1: train 768, test 92, auc 0.5448960302457467, precision 0.5128205128205128,recall 0.8695652173913043, accuracy 0.5217391304347826, f1-score 0.6451612903225806
# {'max_depth': 40, 'n_estimators': 200}
# term11: train 1200, test 134, auc 0.5621519269325016, precision 0.5172413793103449,recall 0.8955223880597015, accuracy 0.5298507462686567, f1-score 0.6557377049180328
# {'max_depth': 40, 'n_estimators': 200}
# term8: train 1274, test 156, auc 0.14792899408284024, precision 0.7831325301204819,recall 0.8333333333333334, accuracy 0.8012820512820513, f1-score 0.8074534161490683
# {'max_depth': 40, 'n_estimators': 200}
# term0: train 370, test 52, auc 0.30917159763313606, precision 0.5714285714285714,recall 0.7692307692307693, accuracy 0.5961538461538461, f1-score 0.6557377049180327
# {'max_depth': 40, 'n_estimators': 200}
# term13: train 734, test 64, auc 0.36572265625, precision 0.6,recall 0.75, accuracy 0.625, f1-score 0.6666666666666665
# {'max_depth': 40, 'n_estimators': 200}
# term17: train 640, test 70, auc 0.463265306122449, precision 0.5423728813559322,recall 0.9142857142857143, accuracy 0.5714285714285714, f1-score 0.6808510638297872
# {'max_depth': 40, 'n_estimators': 200}
# term3: train 598, test 90, auc 0.4, precision 0.5238095238095238,recall 0.7333333333333333, accuracy 0.5333333333333333, f1-score 0.611111111111111
# {'max_depth': 40, 'n_estimators': 200}
# term7: train 1326, test 142, auc 0.14630033723467567, precision 0.7317073170731707,recall 0.8450704225352113, accuracy 0.7676056338028169, f1-score 0.7843137254901961
# {'max_depth': 40, 'n_estimators': 200}
# term9: train 740, test 106, auc 0.21858312566749732, precision 0.803921568627451,recall 0.7735849056603774, accuracy 0.7924528301886793, f1-score 0.7884615384615384
# {'max_depth': 40, 'n_estimators': 200}
# term2: train 366, test 54, auc 0.37585733882030176, precision 0.6129032258064516,recall 0.7037037037037037, accuracy 0.6296296296296297, f1-score 0.6551724137931035
# {'max_depth': 40, 'n_estimators': 200}
# term10: train 784, test 98, auc 0.13202832153269473, precision 0.7540983606557377,recall 0.9387755102040817, accuracy 0.8163265306122449, f1-score 0.8363636363636363
# {'max_depth': 40, 'n_estimators': 200}
# term14: train 68, test 14, auc 0.4897959183673469, precision 0.5,recall 0.42857142857142855, accuracy 0.5, f1-score 0.4615384615384615
# {'max_depth': 40, 'n_estimators': 200}
# term4: train 786, test 110, auc 0.3223140495867769, precision 0.5487804878048781,recall 0.8181818181818182, accuracy 0.5727272727272728, f1-score 0.656934306569343
# {'max_depth': 40, 'n_estimators': 200}
# term18: train 920, test 108, auc 0.4885116598079561, precision 0.5051546391752577,recall 0.9074074074074074, accuracy 0.5092592592592593, f1-score 0.6490066225165563
# {'max_depth': 40, 'n_estimators': 200}
# term6: train 740, test 82, auc 0.20047590719809638, precision 0.6923076923076923,recall 0.8780487804878049, accuracy 0.7439024390243902, f1-score 0.7741935483870966
# {'max_depth': 40, 'n_estimators': 200}
# term22: train 306, test 46, auc 0.10302457466918713, precision 0.8,recall 0.8695652173913043, accuracy 0.8260869565217391, f1-score 0.8333333333333333
# {'max_depth': 40, 'n_estimators': 200}
# term21: train 212, test 40, auc 0.31125, precision 0.5925925925925926,recall 0.8, accuracy 0.625, f1-score 0.6808510638297872
# {'max_depth': 40, 'n_estimators': 200}
# term20: train 418, test 56, auc 0.3877551020408163, precision 0.5666666666666667,recall 0.6071428571428571, accuracy 0.5714285714285714, f1-score 0.5862068965517241
# {'max_depth': 60, 'n_estimators': 50}
# term12: train 472, test 66, auc 0.12350780532598712, precision 0.7435897435897436,recall 0.8787878787878788, accuracy 0.7878787878787878, f1-score 0.8055555555555556
# {'max_depth': 60, 'n_estimators': 50}
# term5: train 808, test 124, auc 0.17169614984391257, precision 0.7428571428571429,recall 0.8387096774193549, accuracy 0.7741935483870968, f1-score 0.787878787878788
# {'max_depth': 60, 'n_estimators': 50}
# term15: train 1514, test 190, auc 0.3905817174515236, precision 0.5639097744360902,recall 0.7894736842105263, accuracy 0.5894736842105263, f1-score 0.6578947368421052
# {'max_depth': 60, 'n_estimators': 50}
# term16: train 1004, test 242, auc 0.5, precision 0.5,recall 1.0, accuracy 0.5, f1-score 0.6666666666666666
# {'max_depth': 60, 'n_estimators': 50}
# term1: train 768, test 92, auc 0.5366257088846881, precision 0.5128205128205128,recall 0.8695652173913043, accuracy 0.5217391304347826, f1-score 0.6451612903225806
# {'max_depth': 60, 'n_estimators': 50}
# term11: train 1200, test 134, auc 0.5549120071285365, precision 0.5087719298245614,recall 0.8656716417910447, accuracy 0.5149253731343284, f1-score 0.6408839779005525
# {'max_depth': 60, 'n_estimators': 50}
# term8: train 1274, test 156, auc 0.15310650887573962, precision 0.7848101265822784,recall 0.7948717948717948, accuracy 0.7884615384615384, f1-score 0.7898089171974522
# {'max_depth': 60, 'n_estimators': 50}
# term0: train 370, test 52, auc 0.3239644970414201, precision 0.5294117647058824,recall 0.6923076923076923, accuracy 0.5384615384615384, f1-score 0.5999999999999999
# {'max_depth': 60, 'n_estimators': 50}
# term13: train 734, test 64, auc 0.361328125, precision 0.6216216216216216,recall 0.71875, accuracy 0.640625, f1-score 0.6666666666666667
# {'max_depth': 60, 'n_estimators': 50}
# term17: train 640, test 70, auc 0.4889795918367347, precision 0.5614035087719298,recall 0.9142857142857143, accuracy 0.6, f1-score 0.6956521739130436
# {'max_depth': 60, 'n_estimators': 50}
# term3: train 598, test 90, auc 0.39555555555555555, precision 0.5161290322580645,recall 0.7111111111111111, accuracy 0.5222222222222223, f1-score 0.5981308411214953
# {'max_depth': 60, 'n_estimators': 50}
# term7: train 1326, test 142, auc 0.13608411029557627, precision 0.7407407407407407,recall 0.8450704225352113, accuracy 0.7746478873239436, f1-score 0.7894736842105262
# {'max_depth': 60, 'n_estimators': 50}
# term9: train 740, test 106, auc 0.21947312210751155, precision 0.7959183673469388,recall 0.7358490566037735, accuracy 0.7735849056603774, f1-score 0.7647058823529412
# {'max_depth': 60, 'n_estimators': 50}
# term2: train 366, test 54, auc 0.3779149519890261, precision 0.5806451612903226,recall 0.6666666666666666, accuracy 0.5925925925925926, f1-score 0.6206896551724138
# {'max_depth': 60, 'n_estimators': 50}
# term10: train 784, test 98, auc 0.14972927946688877, precision 0.7666666666666667,recall 0.9387755102040817, accuracy 0.826530612244898, f1-score 0.8440366972477065
# {'max_depth': 60, 'n_estimators': 50}
# term14: train 68, test 14, auc 0.4285714285714286, precision 0.5,recall 0.5714285714285714, accuracy 0.5, f1-score 0.5333333333333333
# {'max_depth': 60, 'n_estimators': 50}
# term4: train 786, test 110, auc 0.3239669421487604, precision 0.5357142857142857,recall 0.8181818181818182, accuracy 0.5545454545454546, f1-score 0.6474820143884892
# {'max_depth': 60, 'n_estimators': 50}
# term18: train 920, test 108, auc 0.49417009602194795, precision 0.5051546391752577,recall 0.9074074074074074, accuracy 0.5092592592592593, f1-score 0.6490066225165563
# {'max_depth': 60, 'n_estimators': 50}
# term6: train 740, test 82, auc 0.2046400951814396, precision 0.68,recall 0.8292682926829268, accuracy 0.7195121951219512, f1-score 0.7472527472527474
# {'max_depth': 60, 'n_estimators': 50}
# term22: train 306, test 46, auc 0.0992438563327032, precision 0.7727272727272727,recall 0.7391304347826086, accuracy 0.7608695652173914, f1-score 0.7555555555555555
# {'max_depth': 60, 'n_estimators': 50}
# term21: train 212, test 40, auc 0.33375000000000005, precision 0.5454545454545454,recall 0.6, accuracy 0.55, f1-score 0.5714285714285713
# {'max_depth': 60, 'n_estimators': 50}
# term20: train 418, test 56, auc 0.42538265306122447, precision 0.6071428571428571,recall 0.6071428571428571, accuracy 0.6071428571428571, f1-score 0.6071428571428571
# {'max_depth': 60, 'n_estimators': 100}
# term12: train 472, test 66, auc 0.12672176308539942, precision 0.75,recall 0.9090909090909091, accuracy 0.803030303030303, f1-score 0.821917808219178
# {'max_depth': 60, 'n_estimators': 100}
# term5: train 808, test 124, auc 0.1750780437044745, precision 0.7205882352941176,recall 0.7903225806451613, accuracy 0.7419354838709677, f1-score 0.7538461538461538
# {'max_depth': 60, 'n_estimators': 100}
# term15: train 1514, test 190, auc 0.3914127423822714, precision 0.5579710144927537,recall 0.8105263157894737, accuracy 0.5842105263157895, f1-score 0.6609442060085836
# {'max_depth': 60, 'n_estimators': 100}
# term16: train 1004, test 242, auc 0.5, precision 0.5,recall 1.0, accuracy 0.5, f1-score 0.6666666666666666
# {'max_depth': 60, 'n_estimators': 100}
# term1: train 768, test 92, auc 0.5446597353497165, precision 0.5064935064935064,recall 0.8478260869565217, accuracy 0.5108695652173914, f1-score 0.6341463414634146
# {'max_depth': 60, 'n_estimators': 100}
# term11: train 1200, test 134, auc 0.5732902650924482, precision 0.5172413793103449,recall 0.8955223880597015, accuracy 0.5298507462686567, f1-score 0.6557377049180328
# {'max_depth': 60, 'n_estimators': 100}
# term8: train 1274, test 156, auc 0.15014792899408286, precision 0.7777777777777778,recall 0.8076923076923077, accuracy 0.7884615384615384, f1-score 0.7924528301886792
# {'max_depth': 60, 'n_estimators': 100}
# term0: train 370, test 52, auc 0.3313609467455621, precision 0.5454545454545454,recall 0.6923076923076923, accuracy 0.5576923076923077, f1-score 0.6101694915254238
# {'max_depth': 60, 'n_estimators': 100}
# term13: train 734, test 64, auc 0.35888671875, precision 0.6153846153846154,recall 0.75, accuracy 0.640625, f1-score 0.676056338028169
# {'max_depth': 60, 'n_estimators': 100}
# term17: train 640, test 70, auc 0.46571428571428564, precision 0.5614035087719298,recall 0.9142857142857143, accuracy 0.6, f1-score 0.6956521739130436
# {'max_depth': 60, 'n_estimators': 100}
# term3: train 598, test 90, auc 0.4098765432098765, precision 0.5238095238095238,recall 0.7333333333333333, accuracy 0.5333333333333333, f1-score 0.611111111111111
# {'max_depth': 60, 'n_estimators': 100}
# term7: train 1326, test 142, auc 0.13717516365800436, precision 0.7349397590361446,recall 0.8591549295774648, accuracy 0.7746478873239436, f1-score 0.7922077922077921
# {'max_depth': 60, 'n_estimators': 100}
# term9: train 740, test 106, auc 0.2207191171235315, precision 0.7916666666666666,recall 0.7169811320754716, accuracy 0.7641509433962265, f1-score 0.7524752475247525
# {'max_depth': 60, 'n_estimators': 100}
# term2: train 366, test 54, auc 0.37448559670781895, precision 0.5757575757575758,recall 0.7037037037037037, accuracy 0.5925925925925926, f1-score 0.6333333333333334
# {'max_depth': 60, 'n_estimators': 100}
# term10: train 784, test 98, auc 0.1364014993752603, precision 0.75,recall 0.9183673469387755, accuracy 0.8061224489795918, f1-score 0.8256880733944955
# {'max_depth': 60, 'n_estimators': 100}
# term14: train 68, test 14, auc 0.47959183673469385, precision 0.5,recall 0.5714285714285714, accuracy 0.5, f1-score 0.5333333333333333
# {'max_depth': 60, 'n_estimators': 100}
# term4: train 786, test 110, auc 0.32727272727272727, precision 0.5609756097560976,recall 0.8363636363636363, accuracy 0.5909090909090909, f1-score 0.6715328467153284
# {'max_depth': 60, 'n_estimators': 100}
# term18: train 920, test 108, auc 0.4922839506172839, precision 0.5051546391752577,recall 0.9074074074074074, accuracy 0.5092592592592593, f1-score 0.6490066225165563
# {'max_depth': 60, 'n_estimators': 100}
# term6: train 740, test 82, auc 0.19928613920285543, precision 0.72,recall 0.8780487804878049, accuracy 0.7682926829268293, f1-score 0.7912087912087912
# {'max_depth': 60, 'n_estimators': 100}
# term22: train 306, test 46, auc 0.11153119092627599, precision 0.8,recall 0.8695652173913043, accuracy 0.8260869565217391, f1-score 0.8333333333333333
# {'max_depth': 60, 'n_estimators': 100}
# term21: train 212, test 40, auc 0.3175, precision 0.5833333333333334,recall 0.7, accuracy 0.6, f1-score 0.6363636363636365
# {'max_depth': 60, 'n_estimators': 100}
# term20: train 418, test 56, auc 0.4113520408163265, precision 0.5862068965517241,recall 0.6071428571428571, accuracy 0.5892857142857143, f1-score 0.5964912280701754
# {'max_depth': 60, 'n_estimators': 200}
# term12: train 472, test 66, auc 0.1271808999081726, precision 0.725,recall 0.8787878787878788, accuracy 0.7727272727272727, f1-score 0.7945205479452054
# {'max_depth': 60, 'n_estimators': 200}
# term5: train 808, test 124, auc 0.16298126951092612, precision 0.7272727272727273,recall 0.7741935483870968, accuracy 0.7419354838709677, f1-score 0.7500000000000001
# {'max_depth': 60, 'n_estimators': 200}
# term15: train 1514, test 190, auc 0.39002770083102495, precision 0.5664335664335665,recall 0.8526315789473684, accuracy 0.6, f1-score 0.680672268907563
# {'max_depth': 60, 'n_estimators': 200}
# term16: train 1004, test 242, auc 0.5, precision 0.5,recall 1.0, accuracy 0.5, f1-score 0.6666666666666666
# {'max_depth': 60, 'n_estimators': 200}
# term1: train 768, test 92, auc 0.5448960302457467, precision 0.5128205128205128,recall 0.8695652173913043, accuracy 0.5217391304347826, f1-score 0.6451612903225806
# {'max_depth': 60, 'n_estimators': 200}
# term11: train 1200, test 134, auc 0.5621519269325016, precision 0.5172413793103449,recall 0.8955223880597015, accuracy 0.5298507462686567, f1-score 0.6557377049180328
# {'max_depth': 60, 'n_estimators': 200}
# term8: train 1274, test 156, auc 0.14792899408284024, precision 0.7831325301204819,recall 0.8333333333333334, accuracy 0.8012820512820513, f1-score 0.8074534161490683
# {'max_depth': 60, 'n_estimators': 200}
# term0: train 370, test 52, auc 0.30917159763313606, precision 0.5714285714285714,recall 0.7692307692307693, accuracy 0.5961538461538461, f1-score 0.6557377049180327
# {'max_depth': 60, 'n_estimators': 200}
# term13: train 734, test 64, auc 0.36572265625, precision 0.6,recall 0.75, accuracy 0.625, f1-score 0.6666666666666665
# {'max_depth': 60, 'n_estimators': 200}
# term17: train 640, test 70, auc 0.463265306122449, precision 0.5423728813559322,recall 0.9142857142857143, accuracy 0.5714285714285714, f1-score 0.6808510638297872
# {'max_depth': 60, 'n_estimators': 200}
# term3: train 598, test 90, auc 0.4, precision 0.5238095238095238,recall 0.7333333333333333, accuracy 0.5333333333333333, f1-score 0.611111111111111
# {'max_depth': 60, 'n_estimators': 200}
# term7: train 1326, test 142, auc 0.14630033723467567, precision 0.7317073170731707,recall 0.8450704225352113, accuracy 0.7676056338028169, f1-score 0.7843137254901961
# {'max_depth': 60, 'n_estimators': 200}
# term9: train 740, test 106, auc 0.21858312566749732, precision 0.803921568627451,recall 0.7735849056603774, accuracy 0.7924528301886793, f1-score 0.7884615384615384
# {'max_depth': 60, 'n_estimators': 200}
# term2: train 366, test 54, auc 0.37585733882030176, precision 0.6129032258064516,recall 0.7037037037037037, accuracy 0.6296296296296297, f1-score 0.6551724137931035
# {'max_depth': 60, 'n_estimators': 200}
# term10: train 784, test 98, auc 0.13202832153269473, precision 0.7540983606557377,recall 0.9387755102040817, accuracy 0.8163265306122449, f1-score 0.8363636363636363
# {'max_depth': 60, 'n_estimators': 200}
# term14: train 68, test 14, auc 0.4897959183673469, precision 0.5,recall 0.42857142857142855, accuracy 0.5, f1-score 0.4615384615384615
# {'max_depth': 60, 'n_estimators': 200}
# term4: train 786, test 110, auc 0.3223140495867769, precision 0.5487804878048781,recall 0.8181818181818182, accuracy 0.5727272727272728, f1-score 0.656934306569343
# {'max_depth': 60, 'n_estimators': 200}
# term18: train 920, test 108, auc 0.4885116598079561, precision 0.5051546391752577,recall 0.9074074074074074, accuracy 0.5092592592592593, f1-score 0.6490066225165563
# {'max_depth': 60, 'n_estimators': 200}
# term6: train 740, test 82, auc 0.20047590719809638, precision 0.6923076923076923,recall 0.8780487804878049, accuracy 0.7439024390243902, f1-score 0.7741935483870966
# {'max_depth': 60, 'n_estimators': 200}
# term22: train 306, test 46, auc 0.10302457466918713, precision 0.8,recall 0.8695652173913043, accuracy 0.8260869565217391, f1-score 0.8333333333333333
# {'max_depth': 60, 'n_estimators': 200}
# term21: train 212, test 40, auc 0.31125, precision 0.5925925925925926,recall 0.8, accuracy 0.625, f1-score 0.6808510638297872
# {'max_depth': 60, 'n_estimators': 200}
# term20: train 418, test 56, auc 0.3877551020408163, precision 0.5666666666666667,recall 0.6071428571428571, accuracy 0.5714285714285714, f1-score 0.5862068965517241
# {'max_depth': 80, 'n_estimators': 50}
# term12: train 472, test 66, auc 0.12350780532598712, precision 0.7435897435897436,recall 0.8787878787878788, accuracy 0.7878787878787878, f1-score 0.8055555555555556
# {'max_depth': 80, 'n_estimators': 50}
# term5: train 808, test 124, auc 0.17169614984391257, precision 0.7428571428571429,recall 0.8387096774193549, accuracy 0.7741935483870968, f1-score 0.787878787878788
# {'max_depth': 80, 'n_estimators': 50}
# term15: train 1514, test 190, auc 0.3905817174515236, precision 0.5639097744360902,recall 0.7894736842105263, accuracy 0.5894736842105263, f1-score 0.6578947368421052
# {'max_depth': 80, 'n_estimators': 50}
# term16: train 1004, test 242, auc 0.5, precision 0.5,recall 1.0, accuracy 0.5, f1-score 0.6666666666666666
# {'max_depth': 80, 'n_estimators': 50}
# term1: train 768, test 92, auc 0.5366257088846881, precision 0.5128205128205128,recall 0.8695652173913043, accuracy 0.5217391304347826, f1-score 0.6451612903225806
# {'max_depth': 80, 'n_estimators': 50}
# term11: train 1200, test 134, auc 0.5549120071285365, precision 0.5087719298245614,recall 0.8656716417910447, accuracy 0.5149253731343284, f1-score 0.6408839779005525
# {'max_depth': 80, 'n_estimators': 50}
# term8: train 1274, test 156, auc 0.15310650887573962, precision 0.7848101265822784,recall 0.7948717948717948, accuracy 0.7884615384615384, f1-score 0.7898089171974522
# {'max_depth': 80, 'n_estimators': 50}
# term0: train 370, test 52, auc 0.3239644970414201, precision 0.5294117647058824,recall 0.6923076923076923, accuracy 0.5384615384615384, f1-score 0.5999999999999999
# {'max_depth': 80, 'n_estimators': 50}
# term13: train 734, test 64, auc 0.361328125, precision 0.6216216216216216,recall 0.71875, accuracy 0.640625, f1-score 0.6666666666666667
# {'max_depth': 80, 'n_estimators': 50}
# term17: train 640, test 70, auc 0.4889795918367347, precision 0.5614035087719298,recall 0.9142857142857143, accuracy 0.6, f1-score 0.6956521739130436
# {'max_depth': 80, 'n_estimators': 50}
# term3: train 598, test 90, auc 0.39555555555555555, precision 0.5161290322580645,recall 0.7111111111111111, accuracy 0.5222222222222223, f1-score 0.5981308411214953
# {'max_depth': 80, 'n_estimators': 50}
# term7: train 1326, test 142, auc 0.13608411029557627, precision 0.7407407407407407,recall 0.8450704225352113, accuracy 0.7746478873239436, f1-score 0.7894736842105262
# {'max_depth': 80, 'n_estimators': 50}
# term9: train 740, test 106, auc 0.21947312210751155, precision 0.7959183673469388,recall 0.7358490566037735, accuracy 0.7735849056603774, f1-score 0.7647058823529412
# {'max_depth': 80, 'n_estimators': 50}
# term2: train 366, test 54, auc 0.3779149519890261, precision 0.5806451612903226,recall 0.6666666666666666, accuracy 0.5925925925925926, f1-score 0.6206896551724138
# {'max_depth': 80, 'n_estimators': 50}
# term10: train 784, test 98, auc 0.14972927946688877, precision 0.7666666666666667,recall 0.9387755102040817, accuracy 0.826530612244898, f1-score 0.8440366972477065
# {'max_depth': 80, 'n_estimators': 50}
# term14: train 68, test 14, auc 0.4285714285714286, precision 0.5,recall 0.5714285714285714, accuracy 0.5, f1-score 0.5333333333333333
# {'max_depth': 80, 'n_estimators': 50}
# term4: train 786, test 110, auc 0.3239669421487604, precision 0.5357142857142857,recall 0.8181818181818182, accuracy 0.5545454545454546, f1-score 0.6474820143884892
# {'max_depth': 80, 'n_estimators': 50}
# term18: train 920, test 108, auc 0.49417009602194795, precision 0.5051546391752577,recall 0.9074074074074074, accuracy 0.5092592592592593, f1-score 0.6490066225165563
# {'max_depth': 80, 'n_estimators': 50}
# term6: train 740, test 82, auc 0.2046400951814396, precision 0.68,recall 0.8292682926829268, accuracy 0.7195121951219512, f1-score 0.7472527472527474
# {'max_depth': 80, 'n_estimators': 50}
# term22: train 306, test 46, auc 0.0992438563327032, precision 0.7727272727272727,recall 0.7391304347826086, accuracy 0.7608695652173914, f1-score 0.7555555555555555
# {'max_depth': 80, 'n_estimators': 50}
# term21: train 212, test 40, auc 0.33375000000000005, precision 0.5454545454545454,recall 0.6, accuracy 0.55, f1-score 0.5714285714285713
# {'max_depth': 80, 'n_estimators': 50}
# term20: train 418, test 56, auc 0.42538265306122447, precision 0.6071428571428571,recall 0.6071428571428571, accuracy 0.6071428571428571, f1-score 0.6071428571428571
# {'max_depth': 80, 'n_estimators': 100}
# term12: train 472, test 66, auc 0.12672176308539942, precision 0.75,recall 0.9090909090909091, accuracy 0.803030303030303, f1-score 0.821917808219178
# {'max_depth': 80, 'n_estimators': 100}
# term5: train 808, test 124, auc 0.1750780437044745, precision 0.7205882352941176,recall 0.7903225806451613, accuracy 0.7419354838709677, f1-score 0.7538461538461538
# {'max_depth': 80, 'n_estimators': 100}
# term15: train 1514, test 190, auc 0.3914127423822714, precision 0.5579710144927537,recall 0.8105263157894737, accuracy 0.5842105263157895, f1-score 0.6609442060085836
# {'max_depth': 80, 'n_estimators': 100}
# term16: train 1004, test 242, auc 0.5, precision 0.5,recall 1.0, accuracy 0.5, f1-score 0.6666666666666666
# {'max_depth': 80, 'n_estimators': 100}
# term1: train 768, test 92, auc 0.5446597353497165, precision 0.5064935064935064,recall 0.8478260869565217, accuracy 0.5108695652173914, f1-score 0.6341463414634146
# {'max_depth': 80, 'n_estimators': 100}
# term11: train 1200, test 134, auc 0.5732902650924482, precision 0.5172413793103449,recall 0.8955223880597015, accuracy 0.5298507462686567, f1-score 0.6557377049180328
# {'max_depth': 80, 'n_estimators': 100}
# term8: train 1274, test 156, auc 0.15014792899408286, precision 0.7777777777777778,recall 0.8076923076923077, accuracy 0.7884615384615384, f1-score 0.7924528301886792
# {'max_depth': 80, 'n_estimators': 100}
# term0: train 370, test 52, auc 0.3313609467455621, precision 0.5454545454545454,recall 0.6923076923076923, accuracy 0.5576923076923077, f1-score 0.6101694915254238
# {'max_depth': 80, 'n_estimators': 100}
# term13: train 734, test 64, auc 0.35888671875, precision 0.6153846153846154,recall 0.75, accuracy 0.640625, f1-score 0.676056338028169
# {'max_depth': 80, 'n_estimators': 100}
# term17: train 640, test 70, auc 0.46571428571428564, precision 0.5614035087719298,recall 0.9142857142857143, accuracy 0.6, f1-score 0.6956521739130436
# {'max_depth': 80, 'n_estimators': 100}
# term3: train 598, test 90, auc 0.4098765432098765, precision 0.5238095238095238,recall 0.7333333333333333, accuracy 0.5333333333333333, f1-score 0.611111111111111
# {'max_depth': 80, 'n_estimators': 100}
# term7: train 1326, test 142, auc 0.13717516365800436, precision 0.7349397590361446,recall 0.8591549295774648, accuracy 0.7746478873239436, f1-score 0.7922077922077921
# {'max_depth': 80, 'n_estimators': 100}
# term9: train 740, test 106, auc 0.2207191171235315, precision 0.7916666666666666,recall 0.7169811320754716, accuracy 0.7641509433962265, f1-score 0.7524752475247525
# {'max_depth': 80, 'n_estimators': 100}
# term2: train 366, test 54, auc 0.37448559670781895, precision 0.5757575757575758,recall 0.7037037037037037, accuracy 0.5925925925925926, f1-score 0.6333333333333334
# {'max_depth': 80, 'n_estimators': 100}
# term10: train 784, test 98, auc 0.1364014993752603, precision 0.75,recall 0.9183673469387755, accuracy 0.8061224489795918, f1-score 0.8256880733944955
# {'max_depth': 80, 'n_estimators': 100}
# term14: train 68, test 14, auc 0.47959183673469385, precision 0.5,recall 0.5714285714285714, accuracy 0.5, f1-score 0.5333333333333333
# {'max_depth': 80, 'n_estimators': 100}
# term4: train 786, test 110, auc 0.32727272727272727, precision 0.5609756097560976,recall 0.8363636363636363, accuracy 0.5909090909090909, f1-score 0.6715328467153284
# {'max_depth': 80, 'n_estimators': 100}
# term18: train 920, test 108, auc 0.4922839506172839, precision 0.5051546391752577,recall 0.9074074074074074, accuracy 0.5092592592592593, f1-score 0.6490066225165563
# {'max_depth': 80, 'n_estimators': 100}
# term6: train 740, test 82, auc 0.19928613920285543, precision 0.72,recall 0.8780487804878049, accuracy 0.7682926829268293, f1-score 0.7912087912087912
# {'max_depth': 80, 'n_estimators': 100}
# term22: train 306, test 46, auc 0.11153119092627599, precision 0.8,recall 0.8695652173913043, accuracy 0.8260869565217391, f1-score 0.8333333333333333
# {'max_depth': 80, 'n_estimators': 100}
# term21: train 212, test 40, auc 0.3175, precision 0.5833333333333334,recall 0.7, accuracy 0.6, f1-score 0.6363636363636365
# {'max_depth': 80, 'n_estimators': 100}
# term20: train 418, test 56, auc 0.4113520408163265, precision 0.5862068965517241,recall 0.6071428571428571, accuracy 0.5892857142857143, f1-score 0.5964912280701754
# {'max_depth': 80, 'n_estimators': 200}
# term12: train 472, test 66, auc 0.1271808999081726, precision 0.725,recall 0.8787878787878788, accuracy 0.7727272727272727, f1-score 0.7945205479452054
# {'max_depth': 80, 'n_estimators': 200}
# term5: train 808, test 124, auc 0.16298126951092612, precision 0.7272727272727273,recall 0.7741935483870968, accuracy 0.7419354838709677, f1-score 0.7500000000000001
# {'max_depth': 80, 'n_estimators': 200}
# term15: train 1514, test 190, auc 0.39002770083102495, precision 0.5664335664335665,recall 0.8526315789473684, accuracy 0.6, f1-score 0.680672268907563
# {'max_depth': 80, 'n_estimators': 200}
# term16: train 1004, test 242, auc 0.5, precision 0.5,recall 1.0, accuracy 0.5, f1-score 0.6666666666666666
# {'max_depth': 80, 'n_estimators': 200}
# term1: train 768, test 92, auc 0.5448960302457467, precision 0.5128205128205128,recall 0.8695652173913043, accuracy 0.5217391304347826, f1-score 0.6451612903225806
# {'max_depth': 80, 'n_estimators': 200}
# term11: train 1200, test 134, auc 0.5621519269325016, precision 0.5172413793103449,recall 0.8955223880597015, accuracy 0.5298507462686567, f1-score 0.6557377049180328
# {'max_depth': 80, 'n_estimators': 200}
# term8: train 1274, test 156, auc 0.14792899408284024, precision 0.7831325301204819,recall 0.8333333333333334, accuracy 0.8012820512820513, f1-score 0.8074534161490683
# {'max_depth': 80, 'n_estimators': 200}
# term0: train 370, test 52, auc 0.30917159763313606, precision 0.5714285714285714,recall 0.7692307692307693, accuracy 0.5961538461538461, f1-score 0.6557377049180327
# {'max_depth': 80, 'n_estimators': 200}
# term13: train 734, test 64, auc 0.36572265625, precision 0.6,recall 0.75, accuracy 0.625, f1-score 0.6666666666666665
# {'max_depth': 80, 'n_estimators': 200}
# term17: train 640, test 70, auc 0.463265306122449, precision 0.5423728813559322,recall 0.9142857142857143, accuracy 0.5714285714285714, f1-score 0.6808510638297872
# {'max_depth': 80, 'n_estimators': 200}
# term3: train 598, test 90, auc 0.4, precision 0.5238095238095238,recall 0.7333333333333333, accuracy 0.5333333333333333, f1-score 0.611111111111111
# {'max_depth': 80, 'n_estimators': 200}
# term7: train 1326, test 142, auc 0.14630033723467567, precision 0.7317073170731707,recall 0.8450704225352113, accuracy 0.7676056338028169, f1-score 0.7843137254901961
# {'max_depth': 80, 'n_estimators': 200}
# term9: train 740, test 106, auc 0.21858312566749732, precision 0.803921568627451,recall 0.7735849056603774, accuracy 0.7924528301886793, f1-score 0.7884615384615384
# {'max_depth': 80, 'n_estimators': 200}
# term2: train 366, test 54, auc 0.37585733882030176, precision 0.6129032258064516,recall 0.7037037037037037, accuracy 0.6296296296296297, f1-score 0.6551724137931035
# {'max_depth': 80, 'n_estimators': 200}
# term10: train 784, test 98, auc 0.13202832153269473, precision 0.7540983606557377,recall 0.9387755102040817, accuracy 0.8163265306122449, f1-score 0.8363636363636363
# {'max_depth': 80, 'n_estimators': 200}
# term14: train 68, test 14, auc 0.4897959183673469, precision 0.5,recall 0.42857142857142855, accuracy 0.5, f1-score 0.4615384615384615
# {'max_depth': 80, 'n_estimators': 200}
# term4: train 786, test 110, auc 0.3223140495867769, precision 0.5487804878048781,recall 0.8181818181818182, accuracy 0.5727272727272728, f1-score 0.656934306569343
# {'max_depth': 80, 'n_estimators': 200}
# term18: train 920, test 108, auc 0.4885116598079561, precision 0.5051546391752577,recall 0.9074074074074074, accuracy 0.5092592592592593, f1-score 0.6490066225165563
# {'max_depth': 80, 'n_estimators': 200}
# term6: train 740, test 82, auc 0.20047590719809638, precision 0.6923076923076923,recall 0.8780487804878049, accuracy 0.7439024390243902, f1-score 0.7741935483870966
# {'max_depth': 80, 'n_estimators': 200}
# term22: train 306, test 46, auc 0.10302457466918713, precision 0.8,recall 0.8695652173913043, accuracy 0.8260869565217391, f1-score 0.8333333333333333
# {'max_depth': 80, 'n_estimators': 200}
# term21: train 212, test 40, auc 0.31125, precision 0.5925925925925926,recall 0.8, accuracy 0.625, f1-score 0.6808510638297872
# {'max_depth': 80, 'n_estimators': 200}
# term20: train 418, test 56, auc 0.3877551020408163, precision 0.5666666666666667,recall 0.6071428571428571, accuracy 0.5714285714285714, f1-score 0.5862068965517241
# [({'max_depth': 20, 'n_estimators': 50}, 0.6854724456598276),
#  ({'max_depth': 20, 'n_estimators': 100}, 0.6960738811617405),
#  ({'max_depth': 20, 'n_estimators': 200}, 0.6965001194230355),
#  ({'max_depth': 40, 'n_estimators': 50}, 0.6856548743030275),
#  ({'max_depth': 40, 'n_estimators': 100}, 0.6951670483586356),
#  ({'max_depth': 40, 'n_estimators': 200}, 0.696406999466795),
#  ({'max_depth': 60, 'n_estimators': 50}, 0.6856548743030275),
#  ({'max_depth': 60, 'n_estimators': 100}, 0.6951670483586356),
#  ({'max_depth': 60, 'n_estimators': 200}, 0.696406999466795),
#  ({'max_depth': 80, 'n_estimators': 50}, 0.6856548743030275),
#  ({'max_depth': 80, 'n_estimators': 100}, 0.6951670483586356),
#  ({'max_depth': 80, 'n_estimators': 200}, 0.696406999466795)]

# %%
score_param
# Out:
# [({'max_depth': 20, 'n_estimators': 50}, 0.6854724456598276),
#  ({'max_depth': 20, 'n_estimators': 100}, 0.6960738811617405),
#  ({'max_depth': 20, 'n_estimators': 200}, 0.6965001194230355),
#  ({'max_depth': 40, 'n_estimators': 50}, 0.6856548743030275),
#  ({'max_depth': 40, 'n_estimators': 100}, 0.6951670483586356),
#  ({'max_depth': 40, 'n_estimators': 200}, 0.696406999466795),
#  ({'max_depth': 60, 'n_estimators': 50}, 0.6856548743030275),
#  ({'max_depth': 60, 'n_estimators': 100}, 0.6951670483586356),
#  ({'max_depth': 60, 'n_estimators': 200}, 0.696406999466795),
#  ({'max_depth': 80, 'n_estimators': 50}, 0.6856548743030275),
#  ({'max_depth': 80, 'n_estimators': 100}, 0.6951670483586356),
#  ({'max_depth': 80, 'n_estimators': 200}, 0.696406999466795)]

# %%
best_params,score = max(score_param,key=lambda x:x[1])
best_params,score
# Out:
# ({'max_depth': 20, 'n_estimators': 200}, 0.6965001194230355)

# %% [markdown]
# ### Test the best parameters

# %%
auc_test = []
for r in rel_test.keys():
    res = train_model_parameter(r,df_train,df_test,best_params)
    print("{}: train {}, test {}, auc {}, accuracy {}, f1-score {}".format(r,res['train'],res['test'],res['AUC'],
                                                              res['precision'],res['recall'],res['accuracy'],res['F1']))
    auc_test.append(res)
# Out:
# {'max_depth': 20, 'n_estimators': 200}
# term21: train 212, test 32, auc 0.35546875, accuracy 0.6190476190476191, f1-score 0.8125
# {'max_depth': 20, 'n_estimators': 200}
# term11: train 1200, test 144, auc 0.5732060185185185, accuracy 0.5, f1-score 0.9027777777777778
# {'max_depth': 20, 'n_estimators': 200}
# term7: train 1326, test 166, auc 0.13775584264769922, accuracy 0.7741935483870968, f1-score 0.8674698795180723
# {'max_depth': 20, 'n_estimators': 200}
# term10: train 784, test 128, auc 0.1082763671875, accuracy 0.8115942028985508, f1-score 0.875
# {'max_depth': 20, 'n_estimators': 200}
# term18: train 920, test 110, auc 0.5193388429752067, accuracy 0.5, f1-score 0.8727272727272727
# {'max_depth': 20, 'n_estimators': 200}
# term6: train 740, test 84, auc 0.13973922902494332, accuracy 0.7358490566037735, f1-score 0.9285714285714286
# {'max_depth': 20, 'n_estimators': 200}
# term8: train 1274, test 180, auc 0.11944444444444442, accuracy 0.8409090909090909, f1-score 0.8222222222222222
# {'max_depth': 20, 'n_estimators': 200}
# term12: train 472, test 60, auc 0.17166666666666666, accuracy 0.6923076923076923, f1-score 0.9
# {'max_depth': 20, 'n_estimators': 200}
# term15: train 1514, test 182, auc 0.38425310952783476, accuracy 0.6014492753623188, f1-score 0.9120879120879121
# {'max_depth': 20, 'n_estimators': 200}
# term5: train 808, test 84, auc 0.23384353741496594, accuracy 0.6727272727272727, f1-score 0.8809523809523809
# {'max_depth': 20, 'n_estimators': 200}
# term16: train 1004, test 262, auc 0.5, accuracy 0.5, f1-score 1.0
# {'max_depth': 20, 'n_estimators': 200}
# term17: train 640, test 74, auc 0.31738495252008764, accuracy 0.5384615384615384, f1-score 0.9459459459459459
# {'max_depth': 20, 'n_estimators': 200}
# term1: train 768, test 118, auc 0.48893995978167193, accuracy 0.5151515151515151, f1-score 0.864406779661017
# {'max_depth': 20, 'n_estimators': 200}
# term3: train 598, test 70, auc 0.40571428571428575, accuracy 0.5769230769230769, f1-score 0.8571428571428571
# {'max_depth': 20, 'n_estimators': 200}
# term20: train 418, test 70, auc 0.3677551020408163, accuracy 0.6578947368421053, f1-score 0.7142857142857143
# {'max_depth': 20, 'n_estimators': 200}
# term2: train 366, test 42, auc 0.30725623582766437, accuracy 0.6071428571428571, f1-score 0.8095238095238095
# {'max_depth': 20, 'n_estimators': 200}
# term0: train 370, test 34, auc 0.2889273356401384, accuracy 0.6666666666666666, f1-score 0.8235294117647058
# {'max_depth': 20, 'n_estimators': 200}
# term13: train 734, test 96, auc 0.2309027777777778, accuracy 0.7017543859649122, f1-score 0.8333333333333334
# {'max_depth': 20, 'n_estimators': 200}
# term4: train 786, test 90, auc 0.5101234567901234, accuracy 0.5, f1-score 0.7777777777777778
# {'max_depth': 20, 'n_estimators': 200}
# term22: train 306, test 34, auc 0.3044982698961938, accuracy 0.6666666666666666, f1-score 0.7058823529411765
# {'max_depth': 20, 'n_estimators': 200}
# term9: train 740, test 78, auc 0.2636423405654175, accuracy 0.6595744680851063, f1-score 0.7948717948717948
# {'max_depth': 20, 'n_estimators': 200}
# term14: train 68, test 4, auc 0.5, accuracy 1.0, f1-score 0.5
# {'max_depth': 20, 'n_estimators': 200}
# term19: train 20, test 6, auc 0.5555555555555556, accuracy 0.5, f1-score 0.3333333333333333

# %%
pd.DataFrame(auc_test).sample(5)
# Out:
#     train  test  tn  fp  fn  tp       AUC  precision    recall  accuracy  \
# 19    306    34  11   6   5  12  0.304498   0.666667  0.705882  0.676471
# 21     68     4   2   0   1   1  0.500000   1.000000  0.500000  0.750000
# 7     472    60  18  12   3  27  0.171667   0.692308  0.900000  0.750000
# 13    598    70  13  22   5  30  0.405714   0.576923  0.857143  0.614286
# 14    418    70  22  13  10  25  0.367755   0.657895  0.714286  0.671429
#
#           F1
# 19  0.685714
# 21  0.666667
# 7   0.782609
# 13  0.689655
# 14  0.684932

# %%
pd.DataFrame(auc_test).mean()
# Out:
# train        698.608696
# test          93.391304
# tn            20.391304
# fp            26.304348
# fn             5.956522
# tp            40.739130
# AUC            0.338421
# precision      0.645144
# recall         0.814537
# accuracy       0.658531
# F1             0.704911
# dtype: float64

# %%
df_res_test = pd.DataFrame(auc_test)

# %%
F1 = computeF1(df_res_test)

# %%
print('Test F1-score: {}'.format(F1))
# Out:
# Test F1-score: 0.7163608562691132
